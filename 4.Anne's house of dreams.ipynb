# %%
import os
DATA_DIR = 'txtfile'
fname = 'Annehouse of dreamsosu.32435058015256-1560302130.txt'
fname = os.path.join(DATA_DIR, fname)
with open(fname, encoding='utf-8') as f:
    text = f.read()
from string import punctuation
no_punct = ''.join([ch for ch in text if ch not in punctuation])
lower_text=no_punct.lower()

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(lower_text) 
  
clean_text = [w for w in word_tokens if not w in stop_words] 
  
clean_text = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        clean_text.append(w) 

stop=['“', '”','’','—']
filtered_word = [w for w in clean_text if not w in stop]

filtered_word = []

for w in clean_text: 
    if w not in stop: 
        filtered_word.append(w) 
        
print(filtered_word)
# Out:
# ['annes', 'house', 'dreams', 'chapter', 'hanks', 'garret', 'green', 'gables', 'done', 'geometry', 'learning', 'teaching', 'said', 'anne', 'shirley', 'trifle', 'vin', 'garret', 'eyes', 'like', 'place', 'garret', 'gray', 'green', 'gables', 'wright', 'across', 'dictively', 'thumped', 'somewhat', 'battered', 'volume', 'euclid', 'big', 'chest', 'books', 'banged', 'lid', 'looking', 'triumph', 'sat', 'upon', 'diana', 'morning', 'sky', 'shadowy', 'suggestive', 'garrets', 'delightful', 'open', 'window', 'anne', 'sat', 'blew', 'sweet', 'scented', 'sunwarm', 'air', 'august', 'afternoon', 'outside', 'poplar', 'boughs', 'rustled', 'tossed', 'wind', 'beyond', 'woods', 'lovers', 'lane', 'wound', 'chanted', 'path', 'old', 'apple', 'orchard', 'still', 'rosy', 'harvests', 'munificently', 'great', 'mountain', 'range', 'snowy', 'clouds', 'bore', 'en', 'window', 'glimpsed', 'distant', 'whitecapped', 'blue', 'sea—the', 'beauti', 'jewel', 'ful', 'st', 'lawrence', 'gulf', 'floats', 'like', 'blue', 'southern', 'sky', 'whose', 'softer', 'sweeter', '1', 'abegweit', 'indian', 'name', 'annes', 'house', 'dreams', '2', 'long', 'forsaken', 'prosaic', 'one', 'prince', 'edward', 'island', 'diana', 'wright', 'three', 'years', 'older', 'last', 'saw', 'grown', 'somewhat', 'matronly', 'inter', 'vening', 'time', 'eyes', 'black', 'brilliant', 'cheeks', 'rosy', 'dimples', 'enchanting', 'longago', 'days', 'anne', 'shirley', 'vowed', 'eternal', 'friendship', 'garden', 'orchard', 'slope', 'arms', 'held', 'small', 'sleeping', 'black', 'curled', 'creature', 'two', 'happy', 'years', 'known', 'world', 'avonlea', 'small', 'anne', 'cordelia', 'avonlea', 'folks', 'knew', 'diana', 'called', 'anne', 'course', 'avonlea', 'folks', 'puzzled', 'cordelia', 'never', 'cordelia', 'wright', 'barry', 'connections', 'mrs', 'harmon', 'sense', 'allow', 'smiled', 'andrews', 'said', 'supposed', 'diana', 'found', 'name', 'trashy', 'novel', 'wondered', 'fred', 'hadnt', 'diana', 'anne', 'knew', 'small', 'anne', 'cordelia', 'come', 'name', 'always', 'hated', 'geometry', 'past', 'three', 'years', 'likely', 'find', 'married', 'expected', 'evi', 'hamlets', 'opinion', 'much', 'better', 'teaching', 'came', 'home', 'dently', 'mrs', 'harmon', 'mrs', 'harmon', 'andrews', 'told', 'life', 'summerside', 'pleasant', 'ones', 'try', 'said', 'diana', 'retrospective', 'smile', 'think', 'real', 'glad', 'teaching', 'anyhow', 'oh', 'always', 'liked', 'teaching', 'apart', 'geome', 'garret', 'may', 'better', 'bear', 'ills', 'others', 'know', 'fly', '3', 'compounding', 'blue', 'plum', 'preserve', 'heard', 'yore', 'blithe', 'irresistible', 'added', 'note', 'sweetness', 'maturity', 'rang', 'garret', 'marilla', 'kitchen', 'annes', 'laugh', 'smiled', 'think', 'seldom', 'dear', 'laugh', 'would', 'echo', 'green', 'gables', 'years', 'come', 'nothing', 'life', 'ever', 'given', 'marilla', 'sighed', 'three', 'home', 'often', 'sorrow', 'could', 'much', 'visit', 'would', 'summerside', 'years', 'anne', 'vacations', 'weekends', 'little', 'shadow', 'much', 'happiness', 'knowledge', 'anne', 'go', 'ing', 'marry', 'gilbert', 'blythe', 'every', 'joy', 'must', 'bring', 'biannual', 'hoped', 'let', 'mrs', 'harmon', 'says', 'worry', 'said', 'diana', 'calm', 'assurance', 'fouryears', 'matron', 'ups', 'married', 'life', 'downs', 'course', 'mustnt', 'expect', 'every', 'thing', 'always', 'go', 'smoothly', 'assure', 'anne', 'happy', 'life', 'married', 'smile', 'daresay', 'ill', 'perience', 'always', 'amused', 'dianas', 'airs', 'vast', 'anne', 'smothered', 'right', 'man', 'ex', 'little', 'putting', 'settled', 'yet', 'going', 'married', 'four', 'years', 'thought', 'surely', 'though', 'sense', 'humour', 'preserve', 'live', 'asked', 'diana', 'cuddling', 'small', 'anne', 'cordelia', 'annes', 'house', 'dreams', '4', 'inimitable', 'gesture', 'motherhood', 'always', 'sent', 'annes', 'heart', 'filled', 'sweet', 'unuttered', 'dreams', 'hopes', 'thrill', 'half', 'pure', 'pleasure', 'half', 'strange', 'ethereal', 'pain', 'yes', 'wanted', 'tell', 'way', 'real ...

# %%
from collections import Counter
freq = Counter(filtered_text)
freq.most_common
# Out:
# <bound method Counter.most_common of Counter({'anne': 708, 'said': 503, 'house': 355, 'leslie': 334, 'captain': 315, 'little': 293, 'jim': 291, 'never': 289, 'like': 287, 'miss': 284, 'gilbert': 275, 'would': 260, 'cornelia': 250, 'one': 245, 'old': 231, 'dreams': 224, 'know': 206, 'well': 198, 'annes': 193, 'mrs': 173, 'come': 164, 'see': 162, 'could': 159, 'think': 156, 'oh': 153, 'man': 140, 'life': 136, 'home': 130, 'ever': 128, 'much': 127, 'always': 124, 'good': 123, 'thought': 120, 'four': 119, 'got': 119, 'doctor': 119, 'dick': 119, 'went': 118, 'years': 115, 'go': 115, 'must': 115, 'time': 114, 'first': 113, 'winds': 109, 'came': 108, 'going': 108, 'day': 105, 'away': 104, 'blythe': 102, 'tell': 101, 'dear': 99, 'moore': 97, 'harbour': 97, 'get': 95, 'eyes': 93, 'long': 91, 'owen': 90, 'told': 89, 'poor': 87, 'believe': 87, 'married': 84, 'thing': 84, 'night': 84, 'back': 82, 'theres': 81, 'us': 81, 'say': 79, 'glen': 79, 'even': 79, 'love': 78, '‘': 77, 'last': 76, 'looked': 76, 'says': 74, 'right': 74, 'way': 74, 'mistress': 74, 'made': 73, 'knew': 73, 'great': 72, 'im': 72, 'make': 72, 'asked': 71, 'beautiful': 71, 'susan': 71, 'evening': 70, 'might': 70, 'two': 69, 'want': 68, 'yet': 66, 'things': 66, 'ford': 65, 'look': 65, 'hes': 64, 'place': 63, 'dont': 63, 'felt': 63, 'many': 62, 'real': 62, 'big': 61, 'light': 61, 'saw': 61, 'take': 61, 'sea': 61, 'something': 61, 'shore': 60, 'heard': 59, 'found': 58, 'marilla': 58, 'every': 57, 'seemed': 56, 'since': 56, 'face': 56, 'may': 55, 'yes': 55, 'mind': 55, 'girl': 55, 'days': 54, 'glad': 54, 'nothing': 54, 'feel': 54, 'put': 54, 'new': 53, 'world': 53, 'let': 53, 'really': 53, 'seen': 52, 'quite': 52, 'baby': 52, 'people': 51, 'ing': 51, 'ill': 51, 'thats': 51, 'white': 51, 'gone': 51, 'men': 51, 'bride': 50, 'find': 50, 'ago': 50, 'happy': 49, 'enough': 49, 'young': 49, 'dearie': 49, 'heart': 48, 'course': 48, 'another': 48, 'alone': 48, 'anything': 47, 'give': 47, 'hand': 47, 'took': 47, 'story': 46, 'live': 46, 'green': 45, 'child': 45, 'chapter': 44, 'done': 44, 'still': 44, 'talk': 44, 'head': 44, 'rather': 44, 'call': 43, 'garden': 43, 'though': 43, 'better': 42, 'mother': 42, 'year': 42, 'summer': 42, 'book': 41, 'soul': 41, 'best': 41, 'point': 40, 'red': 40, 'mr': 40, 'suppose': 40, 'everything': 40, 'jest': 40, 'coming': 39, 'seems': 39, 'shes': 39, 'door': 39, 'church': 39, 'friends': 38, 'blue': 38, 'matter': 38, 'shall': 38, 'room': 38, 'hair': 38, 'left': 38, 'reckon': 38, 'lost': 37, 'across': 37, 'often': 37, 'along': 37, 'soon': 37, 'brought': 37, 'wasnt': 37, 'times': 37, 'hard': 37, 'woman': 37, 'used': 36, 'folks': 36, 'isnt': 36, 'seem': 36, 'nice': 36, 'died': 36, 'dead': 36, 'else': 36, 'around': 36, 'kind': 36, 'leslies': 36, 'work': 35, 'spring': 35, 'morning': 35, 'name': 35, 'hope': 35, 'didnt': 35, 'sure': 35, 'far': 35, 'leave': 35, 'marshall': 35, 'gave': 34, 'wife': 34, 'word': 34, 'living': 34, 'dave': 34, 'comes': 33, 'almost': 33, 'afraid': 33, 'called': 32, 'wanted': 32, 'couldnt': 32, 'remember': 32, 'rose': 32, 'moment': 32, 'knows': 32, 'gables': 31, 'friend': 31, 'lifebook': 31, 'beauty': 31, 'beyond': 31, 'hear': 31, 'wish': 31, 'full': 31, 'hed': 31, 'rachel': 30, 'laughed': 30, 'mean': 30, 'youll': 30, 'together': 30, 'children': 30, 'loved': 29, 'looking': 29, 'sat': 29, 'half': 29, 'kept': 29, 'help': 29, 'hurt': 29, 'dog': 29, 'without': 28, 'near': 28, 'youre': 28, 'getting': 28, 'lord': 28, 'born': 28, 'wouldnt': 28, 'hands': 28, 'christmas': 27, 'winter': 27, 'bryant': 27, 'sweet': 27, 'laugh': 27, 'strange': 27, 'keep': 27, 'cant': 27, 'wont': 27, 'father': 27, 'next': 27, 'read': 27, 'round': 27, 'three': 26, 'met': 26, 'pretty': 26, 'sometimes': 26, 'stay': 26, 'tonight': 26, 'till': 26, 'ask': 26, 'dr': 25, 'diana': 25, 'gulf': 25, 'looks': 25, 'dress': 25, 'nobody': 25, 'walked': 25, 'fine': 25, 'turned': 25, 'lived': 25, 'jims': 25, 'fire': 25, 'em': 25, 'women': 25, 'cried': 25, 'walk': 24, 'elliott': 24, 'hap ...

# %%
from nltk.probability import FreqDist
Fdist = FreqDist(filtered_text)
print(Fdist)
# Out:
# <FreqDist with 8563 samples and 41983 outcomes>

# %%
Fdist['anne']
# Out:
# 703

# %%
Fdist['anne']/len(word_tokens)
# Out:
# 0.008038695512967113

# %%
Fdist.plot(50, cumulative=True)

# %%
filtered_text=' '.join(filtered_word)

# %%
import os
os.path
# !pip install wordcloud
import wordcloud
from wordcloud import WordCloud
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
wordcloud = WordCloud(max_words=150,background_color="white").generate(filtered_text)
plt.figure(figsize=(16,12))
# plot wordcloud in matplotlib
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Requirement already satisfied: wordcloud in /Applications/anaconda3/lib/python3.7/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /Applications/anaconda3/lib/python3.7/site-packages (from wordcloud) (1.16.2)
# Requirement already satisfied: pillow in /Applications/anaconda3/lib/python3.7/site-packages (from wordcloud) (5.4.1)

# %%
wordcloud.to_file("txtfile/Anne's house of dreams.png")

# %%
import nltk
freqdist = nltk.FreqDist(filtered_word)
plt.figure(figsize=(16,5))
freqdist.plot(50)

# %%
lexical_diversity = len(set(word_tokens)) / len(word_tokens)
lexical_diversity
# Out:
# 0.09967753739194073

# %%
len(set(word_tokens))
# Out:
# 8717

# %%
len(word_tokens)
# Out:
# 87452

# %%
[len(w) for w in word_tokens]
# Out:
# [5,
#  5,
#  2,
#  6,
#  7,
#  2,
#  3,
#  5,
#  1,
#  6,
#  2,
#  5,
#  6,
#  1,
#  1,
#  1,
#  4,
#  4,
#  8,
#  8,
#  2,
#  8,
#  2,
#  1,
#  4,
#  4,
#  7,
#  1,
#  6,
#  3,
#  2,
#  3,
#  2,
#  3,
#  6,
#  3,
#  1,
#  4,
#  4,
#  4,
#  4,
#  5,
#  6,
#  4,
#  4,
#  3,
#  5,
#  6,
#  1,
#  6,
#  6,
#  2,
#  2,
#  9,
#  2,
#  3,
#  7,
#  1,
#  8,
#  8,
#  6,
#  2,
#  6,
#  4,
#  1,
#  3,
#  5,
#  2,
#  5,
#  6,
#  3,
#  3,
#  7,
#  2,
#  7,
#  3,
#  3,
#  4,
#  4,
#  5,
#  7,
#  3,
#  7,
#  10,
#  7,
#  6,
#  2,
#  10,
#  7,
#  3,
#  4,
#  2,
#  2,
#  6,
#  2,
#  5,
#  4,
#  3,
#  4,
#  3,
#  5,
#  7,
#  7,
#  3,
#  3,
#  6,
#  9,
#  7,
#  6,
#  6,
#  7,
#  3,
#  6,
#  3,
#  4,
#  6,
#  4,
#  4,
#  3,
#  5,
#  5,
#  6,
#  4,
#  5,
#  3,
#  7,
#  4,
#  3,
#  3,
#  3,
#  5,
#  7,
#  5,
#  5,
#  3,
#  4,
#  3,
#  4,
#  8,
#  12,
#  5,
#  8,
#  5,
#  5,
#  6,
#  3,
#  2,
#  2,
#  3,
#  1,
#  4,
#  3,
#  2,
#  7,
#  3,
#  5,
#  6,
#  3,
#  8,
#  7,
#  11,
#  4,
#  7,
#  6,
#  5,
#  3,
#  2,
#  8,
#  4,
#  2,
#  5,
#  6,
#  4,
#  1,
#  1,
#  4,
#  8,
#  3,
#  5,
#  6,
#  7,
#  1,
#  8,
#  6,
#  4,
#  3,
#  5,
#  5,
#  2,
#  6,
#  1,
#  4,
#  4,
#  8,
#  3,
#  3,
#  4,
#  7,
#  3,
#  2,
#  6,
#  6,
#  6,
#  5,
#  6,
#  5,
#  5,
#  5,
#  4,
#  4,
#  2,
#  4,
#  3,
#  3,
#  3,
#  5,
#  8,
#  8,
#  2,
#  3,
#  5,
#  6,
#  4,
#  3,
#  3,
#  4,
#  4,
#  2,
#  5,
#  3,
#  9,
#  3,
#  6,
#  2,
#  4,
#  3,
#  3,
#  7,
#  2,
#  10,
#  2,
#  2,
#  3,
#  7,
#  4,
#  4,
#  3,
#  3,
#  4,
#  7,
#  3,
#  5,
#  7,
#  10,
#  2,
#  3,
#  6,
#  2,
#  7,
#  2,
#  5,
#  3,
#  4,
#  3,
#  4,
#  1,
#  5,
#  8,
#  5,
#  6,
#  8,
#  3,
#  3,
#  3,
#  5,
#  5,
#  3,
#  4,
#  5,
#  2,
#  3,
#  5,
#  2,
#  7,
#  2,
#  1,
#  5,
#  4,
#  8,
#  1,
#  7,
#  5,
#  4,
#  3,
#  5,
#  3,
#  6,
#  3,
#  4,
#  2,
#  6,
#  3,
#  7,
#  5,
#  4,
#  7,
#  2,
#  3,
#  8,
#  5,
#  3,
#  5,
#  4,
#  1,
#  8,
#  2,
#  3,
#  6,
#  2,
#  5,
#  11,
#  3,
#  6,
#  2,
#  4,
#  5,
#  4,
#  2,
#  5,
#  6,
#  2,
#  7,
#  4,
#  3,
#  8,
#  5,
#  3,
#  5,
#  3,
#  4,
#  2,
#  4,
#  6,
#  5,
#  3,
#  8,
#  4,
#  4,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  4,
#  3,
#  5,
#  4,
#  4,
#  5,
#  8,
#  3,
#  4,
#  2,
#  3,
#  4,
#  1,
#  3,
#  6,
#  5,
#  8,
#  1,
#  5,
#  4,
#  5,
#  5,
#  6,
#  1,
#  1,
#  6,
#  4,
#  7,
#  8,
#  3,
#  7,
#  7,
#  4,
#  2,
#  2,
#  4,
#  6,
#  4,
#  8,
#  1,
#  1,
#  4,
#  4,
#  4,
#  6,
#  3,
#  6,
#  4,
#  4,
#  3,
#  6,
#  7,
#  4,
#  2,
#  2,
#  4,
#  2,
#  1,
#  4,
#  10,
#  2,
#  4,
#  8,
#  4,
#  2,
#  3,
#  2,
#  2,
#  1,
#  1,
#  2,
#  1,
#  4,
#  5,
#  4,
#  13,
#  5,
#  6,
#  5,
#  3,
#  1,
#  1,
#  4,
#  4,
#  7,
#  4,
#  8,
#  6,
#  1,
#  1,
#  2,
#  1,
#  1,
#  2,
#  6,
#  5,
#  8,
#  5,
#  4,
#  5,
#  2,
#  3,
#  6,
#  3,
#  2,
#  6,
#  2,
#  4,
#  3,
#  4,
#  4,
#  2,
#  4,
#  4,
#  2,
#  6,
#  4,
#  2,
#  4,
#  3,
#  2,
#  1,
#  3,
#  1,
#  11,
#  4,
#  4,
#  8,
#  5,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  4,
#  6,
#  3,
#  12,
#  4,
#  2,
#  5,
#  4,
#  9,
#  3,
#  8,
#  4,
#  7,
#  3,
#  6,
#  7,
#  3,
#  7,
#  5,
#  5,
#  5,
#  3,
#  6,
#  5,
#  3,
#  6,
#  4,
#  4,
#  5,
#  5,
#  4,
#  7,
#  5,
#  6,
#  3,
#  5,
#  4,
#  7,
#  3,
#  4,
#  3,
#  4,
#  5,
#  7,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  6,
#  4,
#  6,
#  3,
#  5,
#  4,
#  5,
#  3,
#  6,
#  1,
#  3,
#  5,
#  2,
#  4,
#  2,
#  2,
#  5,
#  5,
#  2,
#  10,
#  5,
#  4,
#  3,
#  4,
#  9,
#  3,
#  8,
#  3,
#  5,
#  4,
#  1,
#  6,
#  6,
#  2,
#  4,
#  3,
#  2,
#  2,
#  4,
#  9,
#  3,
#  9,
#  4,
#  4,
#  3,
#  2,
#  3,
#  5,
#  7,
#  6,
#  3,
#  5,
#  3,
#  4,
#  5,
#  8,
#  5,
#  3,
#  5,
#  1,
#  1,
#  3,
#  4,
#  3,
#  6,
#  4,
#  5,
#  2,
#  3,
#  2,
#  3,
#  1,
#  4,
#  5,
#  4,
#  3,
#  4,
#  9,
#  3,
#  9,
#  6,
#  3,
#  3,
#  1,
#  7,
#  4,
#  3,
#  5,
#  6,
#  3,
#  6,
#  6,
#  4,
#  5,
#  1,
#  2,
#  1,
#  5,
#  4,
#  6,
#  2,
#  8,
#  3,
#  3,
#  6,
#  3,
#  4,
#  4,
#  3,
#  5,
#  4,
#  4,
#  3,
#  1,
#  2,
#  7,
#  5,
#  7,
#  3,
#  2,
#  1,
#  1,
#  8,
#  6,
#  6,
#  3,
#  6,
#  4,
#  2,
#  4,
#  1,
#  4,
#  9,
#  1,
#  3,
#  5,
#  3,
#  1,
#  2,
#  6,
#  7,
#  4,
#  2,
#  3,
#  4,
#  1,
#  1,
#  2,
#  2,
#  7,
#  3,
#  5,
#  3,
#  3,
#  5,
#  2,
#  1,
#  2,
#  2,
#  2,
#  4,
#  7,
#  4,
#  5,
#  1,
#  3,
#  7,
#  1,
#  6,
#  2,
#  6,
#  1,
#  5,
#  6,
#  4,
#  8,
#  2,
#  4,
#  4,
#  1,
#  5,
#  5,
#  8,
#  5,
#  4,
#  8,
#  4,
#  3,
#  5,
#  5,
#  2,
#  6,
#  1,
#  10,
#  7,
#  2,
#  10,
#  5,
#  6,
#  4,
#  7,
#  5,
#  5,
#  6,
#  4,
#  5,
#  9,
#  6,
#  3,
#  5,
#  1,
#  6,
#  4,
#  3,
#  4,
#  4,
#  8,
#  3,
#  4,
#  1,
#  7,
#  8,
#  4,
#  1,
#  3,
#  1,
#  4,
#  3,
#  4,
#  6,
#  2,
#  4,
#  3,
#  4,
#  1,
#  2,
#  3,
#  3,
#  1,
#  3,
#  1,
#  1,
#  7,
#  4,
#  2,
#  6,
#  4,
#  10,
#  2,
#  4,
#  6,
#  2,
#  3,
#  2,
#  4,
#  4,
#  5,
#  2,
#  3,
#  3,
#  6,
#  2,
#  14,
#  8,
#  3,
#  9,
#  3,
#  4,
#  7,
#  9,
#  3,
#  5,
#  1,
#  1,
#  2,
#  3,
#  5,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  4,
#  1,
#  4,
#  5,
#  1,
#  2,
#  6,
#  5,
#  4,
#  3,
#  3,
#  4,
#  2,
#  4,
#  5,
#  5,
#  3,
#  6,
#  2,
#  3,
#  7,
#  2,
#  7,
#  3,
#  1,
#  2,
#  5,
#  3,
#  6,
#  4,
#  5,
#  6,
#  2,
#  10,
#  3,
#  7,
#  3,
#  4,
#  5,
#  2,
#  12,
#  3,
#  8,
#  5,
#  3,
#  7,
#  4,
#  3,
#  7,
#  2,
#  4,
#  7,
#  4,
#  4,
#  3,
#  2,
#  3,
#  4,
#  3,
#  8,
#  4,
#  3,
#  4,
#  6,
#  3,
#  4,
#  4,
#  3,
#  6,
#  7,
#  6,
#  3,
#  8,
#  8,
#  5,
#  3,
#  6,
#  2,
#  2,
#  1,
#  1,
#  8,
#  2,
#  4,
#  4,
#  4,
#  2,
#  6,
#  1,
#  1,
#  1,
#  1,
#  9,
#  2,
#  3,
#  5,
#  1,
#  3,
#  3,
#  9,
#  1,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  4,
#  6,
#  4,
#  2,
#  2,
#  3,
#  2,
#  2,
#  6,
#  4,
#  2,
#  1,
#  5,
#  1,
#  6,
#  14,
#  2,
#  2,
#  4,
#  2,
#  8,
#  3,
#  4,
#  1,
#  1,
#  4,
#  7,
#  7,
#  5,
#  4,
#  5,
#  2,
#  1,
#  4,
#  2,
#  4,
#  3,
#  10,
#  5,
#  4,
#  1,
#  2,
#  7,
#  1,
#  4,
#  4,
#  2,
#  2,
#  2,
#  2,
#  2,
#  1,
#  4,
#  3,
#  4,
#  15,
#  4,
#  4,
#  10,
#  3,
#  3,
#  6,
#  4,
#  5,
#  2,
#  7,
#  11,
#  3,
#  3,
#  6,
#  4,
#  ...]

# %%
fdist = FreqDist(len(w) for w in word_tokens) 
print(fdist)
fdist
# Out:
# <FreqDist with 23 samples and 87452 outcomes>
# FreqDist({3: 19544, 4: 17816, 2: 13283, 5: 9507, 1: 9107, 6: 6673, 7: 5155, 8: 2821, 9: 1648, 10: 875, ...})

# %%
fdist.most_common()
# Out:
# [(3, 19544),
#  (4, 17816),
#  (2, 13283),
#  (5, 9507),
#  (1, 9107),
#  (6, 6673),
#  (7, 5155),
#  (8, 2821),
#  (9, 1648),
#  (10, 875),
#  (11, 485),
#  (12, 277),
#  (13, 129),
#  (14, 55),
#  (15, 38),
#  (16, 17),
#  (17, 12),
#  (18, 3),
#  (19, 2),
#  (20, 2),
#  (21, 1),
#  (28, 1),
#  (30, 1)]

# %%
fdist.freq(fdist.max())
# Out:
# 0.2234825961670402

# %%
len(text.split())
# Out:
# 82028

# %%
import re
parts = [len(l.split()) for l in re.split(r'[?!.]', text) if l.strip()]

print(sum(parts)/len(parts))
# Out:
# 13.84619230128312

# %%
import nltk
from nltk import pos_tag
nltk.pos_tag(freq)
# Out:
# [('annes', 'NNS'),
#  ('house', 'NN'),
#  ('dreams', 'VBZ'),
#  ('chapter', 'NN'),
#  ('hanks', 'NNS'),
#  ('garret', 'VBP'),
#  ('green', 'JJ'),
#  ('gables', 'NNS'),
#  ('done', 'VBN'),
#  ('geometry', 'NN'),
#  ('learning', 'VBG'),
#  ('teaching', 'VBG'),
#  ('said', 'VBD'),
#  ('anne', 'JJ'),
#  ('shirley', 'NN'),
#  ('trifle', 'NN'),
#  ('vin', 'JJ'),
#  ('eyes', 'NNS'),
#  ('like', 'IN'),
#  ('place', 'NN'),
#  ('gray', 'JJ'),
#  ('wright', 'NN'),
#  ('across', 'IN'),
#  ('dictively', 'RB'),
#  ('thumped', 'VBD'),
#  ('somewhat', 'RB'),
#  ('battered', 'JJ'),
#  ('volume', 'NN'),
#  ('euclid', 'VBD'),
#  ('big', 'JJ'),
#  ('chest', 'NN'),
#  ('books', 'NNS'),
#  ('banged', 'VBD'),
#  ('lid', 'JJ'),
#  ('looking', 'VBG'),
#  ('triumph', 'NN'),
#  ('sat', 'VBD'),
#  ('upon', 'IN'),
#  ('diana', 'JJ'),
#  ('morning', 'NN'),
#  ('sky', 'NN'),
#  ('shadowy', 'NN'),
#  ('suggestive', 'JJ'),
#  ('garrets', 'NNS'),
#  ('delightful', 'JJ'),
#  ('open', 'JJ'),
#  ('window', 'NN'),
#  ('blew', 'VBD'),
#  ('sweet', 'JJ'),
#  ('scented', 'JJ'),
#  ('sunwarm', 'NN'),
#  ('air', 'NN'),
#  ('august', 'JJ'),
#  ('afternoon', 'NN'),
#  ('outside', 'IN'),
#  ('poplar', 'JJ'),
#  ('boughs', 'NNS'),
#  ('rustled', 'VBD'),
#  ('tossed', 'JJ'),
#  ('wind', 'NN'),
#  ('beyond', 'IN'),
#  ('woods', 'NNS'),
#  ('lovers', 'NNS'),
#  ('lane', 'VBP'),
#  ('wound', 'RB'),
#  ('chanted', 'VBN'),
#  ('path', 'NN'),
#  ('old', 'JJ'),
#  ('apple', 'NN'),
#  ('orchard', 'NN'),
#  ('still', 'RB'),
#  ('rosy', 'JJ'),
#  ('harvests', 'NNS'),
#  ('munificently', 'RB'),
#  ('great', 'JJ'),
#  ('mountain', 'NN'),
#  ('range', 'NN'),
#  ('snowy', 'NN'),
#  ('clouds', 'NNS'),
#  ('bore', 'VBD'),
#  ('en', 'NNS'),
#  ('glimpsed', 'VBN'),
#  ('distant', 'JJ'),
#  ('whitecapped', 'VBD'),
#  ('blue', 'JJ'),
#  ('sea—the', 'NN'),
#  ('beauti', 'NN'),
#  ('jewel', 'NN'),
#  ('ful', 'JJ'),
#  ('st', 'NN'),
#  ('lawrence', 'NN'),
#  ('gulf', 'NN'),
#  ('floats', 'NNS'),
#  ('southern', 'VBP'),
#  ('whose', 'WP$'),
#  ('softer', 'JJR'),
#  ('sweeter', 'NN'),
#  ('1', 'CD'),
#  ('abegweit', 'NN'),
#  ('indian', 'JJ'),
#  ('name', 'NN'),
#  ('2', 'CD'),
#  ('long', 'RB'),
#  ('forsaken', 'JJ'),
#  ('prosaic', 'NN'),
#  ('one', 'CD'),
#  ('prince', 'NN'),
#  ('edward', 'NN'),
#  ('island', 'NN'),
#  ('three', 'CD'),
#  ('years', 'NNS'),
#  ('older', 'JJR'),
#  ('last', 'JJ'),
#  ('saw', 'VBD'),
#  ('grown', 'JJ'),
#  ('matronly', 'RB'),
#  ('inter', 'RB'),
#  ('vening', 'VBG'),
#  ('time', 'NN'),
#  ('black', 'JJ'),
#  ('brilliant', 'JJ'),
#  ('cheeks', 'NN'),
#  ('dimples', 'NNS'),
#  ('enchanting', 'VBG'),
#  ('longago', 'JJ'),
#  ('days', 'NNS'),
#  ('vowed', 'VBD'),
#  ('eternal', 'JJ'),
#  ('friendship', 'NN'),
#  ('garden', 'NN'),
#  ('slope', 'NN'),
#  ('arms', 'NNS'),
#  ('held', 'VBD'),
#  ('small', 'JJ'),
#  ('sleeping', 'NN'),
#  ('curled', 'JJ'),
#  ('creature', 'NN'),
#  ('two', 'CD'),
#  ('happy', 'JJ'),
#  ('known', 'VBN'),
#  ('world', 'NN'),
#  ('avonlea', 'NN'),
#  ('cordelia', 'JJ'),
#  ('folks', 'NNS'),
#  ('knew', 'VBD'),
#  ('called', 'VBN'),
#  ('course', 'NN'),
#  ('puzzled', 'VBD'),
#  ('never', 'RB'),
#  ('barry', 'JJ'),
#  ('connections', 'NNS'),
#  ('mrs', 'VBP'),
#  ('harmon', 'JJ'),
#  ('sense', 'NN'),
#  ('allow', 'NN'),
#  ('smiled', 'VBD'),
#  ('andrews', 'NNS'),
#  ('supposed', 'VBN'),
#  ('found', 'VBD'),
#  ('trashy', 'JJ'),
#  ('novel', 'NN'),
#  ('wondered', 'VBD'),
#  ('fred', 'VBN'),
#  ('hadnt', 'JJ'),
#  ('come', 'NN'),
#  ('always', 'RB'),
#  ('hated', 'VBD'),
#  ('past', 'JJ'),
#  ('likely', 'JJ'),
#  ('find', 'NN'),
#  ('married', 'VBD'),
#  ('expected', 'VBN'),
#  ('evi', 'JJ'),
#  ('hamlets', 'NNS'),
#  ('opinion', 'NN'),
#  ('much', 'RB'),
#  ('better', 'RBR'),
#  ('came', 'VBD'),
#  ('home', 'RB'),
#  ('dently', 'RB'),
#  ('told', 'JJ'),
#  ('life', 'NN'),
#  ('summerside', 'NN'),
#  ('pleasant', 'JJ'),
#  ('ones', 'NNS'),
#  ('try', 'VBP'),
#  ('retrospective', 'JJ'),
#  ('smile', 'NN'),
#  ('think', 'VBP'),
#  ('real', 'JJ'),
#  ('glad', 'NN'),
#  ('anyhow', 'NN'),
#  ('oh', 'JJ'),
#  ('liked', 'VBD'),
#  ('apart', 'RB'),
#  ('geome', 'NN'),
#  ('may', 'MD'),
#  ('bear', 'VB'),
#  ('ills', 'NNS'),
#  ('others', 'NNS'),
#  ('know', 'VBP'),
#  ('fly', 'RB'),
#  ('3', 'CD'),
#  ('compounding', 'VBG'),
#  ('plum', 'NN'),
#  ('preserve', 'VB'),
#  ('heard', 'NN'),
#  ('yore', 'IN'),
#  ('blithe', 'NN'),
#  ('irresistible', 'NN'),
#  ('added', 'VBD'),
#  ('note', 'NN'),
#  ('sweetness', 'NN'),
#  ('maturity', 'NN'),
#  ('rang', 'VBP'),
#  ('marilla', 'NN'),
#  ('kitchen', 'NN'),
#  ('laugh', 'IN'),
#  ('seldom', 'NN'),
#  ('dear', 'NN'),
#  ('would', 'MD'),
#  ('echo', 'VB'),
#  ('nothing', 'NN'),
#  ('ever', 'RB'),
#  ('given', 'VBN'),
#  ('sighed', 'VBD'),
#  ('often', 'RB'),
#  ('sorrow', 'JJ'),
#  ('could', 'MD'),
#  ('visit', 'VB'),
#  ('vacations', 'NNS'),
#  ('weekends', 'VBZ'),
#  ('little', 'JJ'),
#  ('shadow', 'JJ'),
#  ('happiness', 'NN'),
#  ('knowledge', 'NN'),
#  ('go', 'VBP'),
#  ('ing', 'VBG'),
#  ('marry', 'NN'),
#  ('gilbert', 'VBP'),
#  ('blythe', 'NN'),
#  ('every', 'DT'),
#  ('joy', 'NN'),
#  ('must', 'MD'),
#  ('bring', 'VB'),
#  ('biannual', 'JJ'),
#  ('hoped', 'VBN'),
#  ('let', 'VB'),
#  ('says', 'VBZ'),
#  ('worry', 'VB'),
#  ('calm', 'JJ'),
#  ('assurance', 'NN'),
#  ('fouryears', 'NNS'),
#  ('matron', 'VBP'),
#  ('ups', 'JJ'),
#  ('downs', 'NNS'),
#  ('mustnt', 'VBP'),
#  ('expect', 'JJ'),
#  ('thing', 'NN'),
#  ('smoothly', 'JJ'),
#  ('assure', 'NN'),
#  ('daresay', 'NN'),
#  ('ill', 'JJ'),
#  ('perience', 'NN'),
#  ('amused', 'VBD'),
#  ('dianas', 'JJ'),
#  ('airs', 'NNS'),
#  ('vast', 'VBP'),
#  ('smothered', 'JJ'),
#  ('right', 'JJ'),
#  ('man', 'NN'),
#  ('ex', 'VBZ'),
#  ('putting', 'VBG'),
#  ('settled', 'VBN'),
#  ('yet', 'RB'),
#  ('going', 'VBG'),
#  ('four', 'CD'),
#  ('thought', 'NN'),
#  ('surely', 'RB'),
#  ('though', 'IN'),
#  ('humour', 'JJ'),
#  ('live', 'JJ'),
#  ('asked', 'VBD'),
#  ('cuddling', 'VBG'),
#  ('4', 'CD'),
#  ('inimitable', 'JJ'),
#  ('gesture', 'NN'),
#  ('motherhood', 'NN'),
#  ('sent', 'VBD'),
#  ('heart', 'NN'),
#  ('filled', 'VBN'),
#  ('unuttered', 'JJ'),
#  ('hopes', 'NNS'),
#  ('thrill', 'IN'),
#  ('half', 'JJ'),
#  ('pure', 'JJ'),
#  ('pleasure', 'NN'),
#  ('strange', 'JJ'),
#  ('ethereal', 'JJ'),
#  ('pain', 'NN'),
#  ('yes', 'RB'),
#  ('wanted', 'VBD'),
#  ('tell', 'JJ'),
#  ('way', 'NN'),
#  ('realise', 'NN'),
#  ('really', 'RB'),
#  ('telephones', 'VBZ'),
#  ('avon', 'NN'),
#  ('phoned', 'VBN'),
#  ('today', 'NN'),
#  ('lea', 'NN'),
#  ('sounds', 'VBZ'),
#  ('preposterously', 'RB'),
#  ('uptodate', 'JJ'),
#  ('modernish', 'JJ'),
#  ('darling', 'VBG'),
#  ('leisurely', 'RB'),
#  ('thank', 'JJ'),
#  ('v', 'NN'),
#  ('got', 'VBD'),
#  ('line', 'NN'),
#  ('taken', 'VBN'),
#  ('matter', 'NN'),
#  ('carried', 'VBD'),
#  ('enough', 'JJ'),
#  ('cold', 'JJ'),
#  ('water', 'NN'),
#  ('thrown', 'VBN'),
#  ('discourage', 'NN'),
#  ('society', 'NN'),
#  ('stuck', 'VBD'),
#  ('nevertheless', 'RB'),
#  ('splendid', 'JJ'),
#  ('founded', 'VBD'),
#  ('fun', 'JJ'),
#  ('meetings', 'NNS'),
#  ('forget', 'VBP'),
#  ('hall', 'JJ'),
#  ('judson', 'NN'),
#  ('parkers', 'NNS'),
#  ('scheme', 'VBP'),
#  ('painting', 'VBG'),
#  ('medicine', 'NN'),
#  ('adver', 'RB'),
#  ('grateful', 'JJ'),
#  ('dont', 'NN'),
#  ('im', 'NN'),
#  ('wholly', 'RB'),
#  ('tisements', 'VBZ'),
#  ('fence', 'NN'),
#  ('telephone', 'NN'),
#  ('kept', 'VBD'),
#  ('calls', 'NNS'),
#  ('‘', 'JJ'),
#  ('modern', 'JJ'),
#  ('inconveniences', 'NNS'),
#  ('mr', 'VBP'),
#  ('harrison', 'NN'),
#  ('want', 'VBP'),
#  ('spoiled', 'VBN'),
#  ('witty', 'JJ'),
#  ('wants', 'VBZ'),
#  ('feel', 'VB'),
#  ('procession', 'NN'),
#  ('thats', 'NNS'),
#  ('somehow', 'VBP'),
#  ('keep', 'VB'),
#  ('convenient—even', 'NN'),
#  ('signalling', 'VBG'),
#  ('device', 'NN'),
#  ('flashes', 'NNS'),
#  ('candlelight', 'VBD'),
#  ('rachel', 'NN'),
#  ('5', 'CD'),
#  ('foolish—and', 'NN'),
#  ('sentimental—and', 'NN'),
#  ('impossible', 'JJ'),
#  ('shall', 'MD'),
#  ('immediately', 'RB'),
#  ('become', 'VB'),
#  ('wise', 'JJ'),
#  ('practical', 'JJ'),
#  ('concedes', 'NNS'),
#  ('buster', 'RB'),
#  ('good', 'JJ'),
#  ('thing—even', 'NN'),
#  ('probably', 'RB'),
#  ('dozen', 'NN'),
#  ('interested', 'JJ'),
#  ('people', 'NNS'),
#  ('listen', 'VBP'),
#  ('possible', 'JJ'),
#  ('along', 'IN'),
#  ('worst', 'JJS'),
#  ('annoying', 'VBG'),
#  ('hear', 'JJ'),
#  ('receivers', 'NNS'),
#  ('whenever', 'WRB'),
#  ('ring', 'VBG'),
#  ('anyone', 'NN'),
#  ('say', 'VBP'),
#  ('insisted', 'VBN'),
#  ('phone', 'NN'),
#  ('put', 'VBD'),
#  ('eye', 'NN'),
#  ('dinner', 'NN'),
#  ('distinctly', 'RB'),
#  ('queer', 'VBZ'),
#  ('clock', 'NN'),
#  ('pyes', 'NNS'),
#  ('striking', 'VBG'),
#  ('doubt', 'NN'),
#  ('josie', 'NN'),
#  ('gertie', 'NN'),
#  ('listening', 'VBG'),
#  ('new', 'JJ'),
#  ('couldnt', 'NN'),
#  ('imagine', 'NN'),
#  ('meant', 'VBP'),
#  ('vicious', 'JJ'),
#  ('click', 'NN'),
#  ('soon', 'RB'),
#  ('spoken', 'VBD'),
#  ('receiver', 'NN'),
#  ('suppose', 'NN'),
#  ('pye', 'NN'),
#  ('hung', 'NN'),
#  ('profane', 'NN'),
#  ('energy', 'NN'),
#  ('mind', 'NN'),
#  ('well', 'RB'),
#  ('without', 'IN'),
#  ('end', 'NN'),
#  ('amen', 'NNS'),
#  ('talk', 'VBP'),
#  ('pleasanter', 'JJ'),
#  ('things', 'NNS'),
#  ('hope', 'VBP'),
#  ('near', 'IN'),
#  ('nooo', 'JJ'),
#  ('drawback', 'NN'),
#  ('settle', 'VB'),
#  ('winds', 'NNS'),
#  ('harbour—sixty', 'JJ'),
#  ('miles', 'NNS'),
#  ('6', 'CD'),
#  ('sixty', 'NN'),
#  ('might', 'MD'),
#  ('six', 'CD'),
#  ('hundred', 'CD'),
#  ('get', 'NNS'),
#  ('charlottetown', 'JJ'),
#  ('beautiful', 'JJ'),
#  ('harbour', 'NN'),
#  ('lage', 'NN'),
#  ('glen', 'VBN'),
#  ('mary', 'JJ'),
#  ('theres', 'NNS'),
#  ('vil', 'VBP'),
#  ('head', 'NN'),
#  ('dr', 'NN'),
#  ('david', 'NN'),
#  ('practising', 'VBG'),
#  ('fifty', 'JJ'),
#  ('gilberts', 'NNS'),
#  ('greatuncle', 'NN'),
#  ('retire', 'VBP'),
#  ('take', 'VB'),
#  ('practice', 'NN'),
#  ('habitation', 'NN'),
#  ('reality', 'NN'),
#  ('imagina', 'VBP'),
#  ('furnished', 'VBN'),
#  ('spain', 'NN'),
#  ('tion—a', 'NN'),
#  ('tiny', 'JJ'),
#  ('castle', 'NN'),
#  ('wedding', 'VBG'),
#  ('tour', 'JJ'),
#  ('look', 'NN'),
#  ('horrified', 'VBD'),
#  ('dearest', 'JJS'),
#  ('suggest', 'NN'),
#  ('nowhere', 'RB'),
#  ('remark', 'VBZ'),
#  ('condescendingly', 'RB'),
#  ('cant', 'JJ'),
#  ('afford', 'NN'),
#  ('towers', 'NNS'),
#  ('sensible', 'JJ'),
#  ('shell', 'NN'),
#  ('remind', 'VB'),
#  ('jane', 'NN'),
#  ('went', 'VBD'),
#  ('europe', 'JJ'),
#  ('spend', 'NN'),
#  ('honeymoon', 'NN'),
#  ('bridesmaid', 'NN'),
#  ('van', 'NN'),
#  ('wont', 'JJ'),
#  ('marriage', 'NN'),
#  ('stella', 'NN'),
#  ('kindred', 'VBD'),
#  ('soul', 'JJ'),
#  ('couver', 'NN'),
#  ('decided', 'VBD'),
#  ('isnt', 'JJ'),
#  ('phil', 'NN'),
#  ('priscilla', 'NN'),
#  ('stole', 'VBD'),
#  ('march', 'NN'),
#  ('wear', 'NN'),
#  ('veil', 'FW'),
#  ('7', 'CD'),
#  ('arent', 'NN'),
#  ('anxiously', 'RB'),
#  ('indeedy', 'JJ'),
#  ('bride', 'IN'),
#  ('remember', 'NN'),
#  ('telling', 'VBG'),
#  ('matthew', 'NN'),
#  ('evening', 'VBG'),
#  ('brought', 'VBD'),
#  ('homely', 'RB'),
#  ('me—unless', 'JJ'),
#  ('foreign', 'JJ'),
#  ('missionary', 'JJ'),
#  ('idea', 'NN'),
#  ('mis', 'NN'),
#  ('sionaries', 'NNS'),
#  ('finicky', 'VBP'),
#  ('looks', 'VBZ'),
#  ('girl', 'JJ'),
#  ('risk', 'NN'),
#  ('among', 'IN'),
#  ('cannibals', 'NNS'),
#  ('seen', 'VBN'),
#  ('sionary', 'JJ'),
#  ('handsome', 'NN'),
#  ('inscrutable', 'JJ'),
#  ('daydreams', 'NNS'),
#  ('planned', 'VBD'),
#  ('best', 'JJS'),
#  ('dressed', 'VBN'),
#  ('met', 'NN'),
#  ('raved', 'VBN'),
#  ('golden', 'JJ'),
#  ('beauty', 'NN'),
#  ('japan', 'NN'),
#  ('dress', 'NN'),
#  ('dream', 'NN'),
#  ('rapturously', 'RB'),
#  ('perfect', 'JJ'),
#  ('queen', 'JJ'),
#  ('it—youre', 'NN'),
#  ('tall', 'JJ'),
#  ('slender', 'NN'),
#  ('slim', 'NN'),
#  ('fatter', 'NN'),
#  ('ever—i', 'VBP'),
#  ('waist', 'NN'),
#  ('stoutness', 'NN'),
#  ('slimness', 'NN'),
#  ('seem', 'VBP'),
#  ('matters', 'NNS'),
#  ('pre', 'VBP'),
#  ('destination', 'NN'),
#  ('events', 'NNS'),
#  ('har', 'JJ'),
#  ('mon', 'JJ'),
#  ('youre', 'NN'),
#  ('skinny', 'VBZ'),
#  ('quite', 'RB'),
#  ('romantic', 'JJ'),
#  ('different', 'JJ'),
#  ('tang', 'NN'),
#  ('8', 'CD'),
#  ('talking', 'VBG'),
#  ('trous', 'JJ'),
#  ('seau', 'NN'),
#  ('admits', 'VBZ'),
#  ('nice', 'JJ'),
#  ('janes', 'NNS'),
#  ('although', 'IN'),
#  ('millionaire', 'NN'),
#  ('mar', 'NN'),
#  ('rying', 'VBG'),
#  ('poor', 'JJ'),
#  ('young', 'JJ'),
#  ('doctor', 'NN'),
#  ('cent', 'NN'),
#  ('laughed', 'VBD'),
#  ('love', 'JJ'),
#  ('pretty', 'RB'),
#  ('member', 'NN'),
#  ('first', 'JJ'),
#  ('had—the', 'NN'),
#  ('brown', 'NN'),
#  ('dresses', 'VBZ'),
#  ('gloria', 'NNS'),
#  ('gave', 'VBD'),
#  ('school', 'NN'),
#  ('concert', 'NN'),
#  ('fore', 'VBD'),
#  ('everything', 'NN'),
#  ('ugly', 'RB'),
#  ('seemed', 'VBD'),
#  ('stepped', 'JJ'),
#  ('night', 'NN'),
#  ('recited', 'VBD'),
#  ('bingen', 'NN'),
#  ('rhine', 'NN'),
#  ('looked', 'VBD'),
#  ('sister', 'RB'),
#  ('furious', 'JJ'),
#  ('pink', 'JJ'),
#  ('tissue', 'NN'),
#  ('rose', 'VBD'),
#  ('breast', 'NN'),
#  ('pocket', 'NN'),
#  ('didnt', 'NN'),
#  ('another', 'DT'),
#  ('instance', 'NN'),
#  ('predestina', 'NN'),
#  ('tion', 'NN'),
#  ('stairs', 'VBZ'),
#  ('ii', 'JJ'),
#  ('excitement', 'NN'),
#  ('history', 'NN'),
#  ('even', 'RB'),
#  ('excited', 'VBD'),
#  ('help', 'NN'),
#  ('showing', 'VBG'),
#  ('it—which', 'JJ'),
#  ('short', 'JJ'),
#  ('phenomenal', 'NN'),
#  ('apologetically', 'RB'),
#  ('lynde', 'JJ'),
#  ('child', 'NN'),
#  ('minister', 'NN'),
#  ('con', 'NN'),
#  ('secrated', 'VBD'),
#  ('birth', 'JJ'),
#  ('death', 'NN'),
#  ('weve', 'VBP'),
#  ('deaths', 'NNS'),
#  ('here—my', 'VB'),
#  ('father', 'RB'),
#  ('mother', 'NN'),
#  ('died', 'VBD'),
#  ('ago', 'RB'),
#  ('moved', 'VBN'),
#  ('hired', 'JJ'),
#  ('wife', 'NN'),
#  ('baby', 'NN'),
#  ('wed', 'VBD'),
#  ('ding', 'VBG'),
#  ('seems', 'VBZ'),
#  ('fourteen', 'JJ'),
#  ('shes', 'NNS'),
#  ('felt', 'VBD'),
#  ('9', 'CD'),
#  ('1o', 'CD'),
#  ('wonder', 'NN'),
#  ('became', 'VBD'),
#  ('boy', 'JJ'),
#  ('mistake', 'NN'),
#  ('fate', 'NN'),
#  ('fortunate', 'NN'),
#  ('so—that', 'WP'),
#  ('see', 'VBP'),
#  ('treated', 'JJ'),
#  ('us', 'PRP'),
#  ('scene', 'VBP'),
#  ('many', 'JJ'),
#  ('changed', 'VBN'),
#  ('since', 'IN'),
#  ('brisked', 'VBN'),
#  ('weddings', 'NNS'),
#  ('order', 'NN'),
#  ('ready', 'JJ'),
#  ('dead', 'JJ'),
#  ('bury', 'NN'),
#  ('give', 'VBP'),
#  ('cotton', 'NN'),
#  ('warp', 'NN'),
#  ('spreads', 'NNS'),
#  ('resumed', 'VBD'),
#  ('tobaccostripe', 'JJ'),
#  ('appleleaf', 'NN'),
#  ('tells', 'NNS'),
#  ('theyre', 'IN'),
#  ('getting', 'VBG'),
#  ('fashionable', 'JJ'),
#  ('fashion', 'NN'),
#  ('believe', 'VBP'),
#  ('anything', 'NN'),
#  ('prettier', 'JJR'),
#  ('spare', 'JJ'),
#  ('room', 'NN'),
#  ('bed', 'VBD'),
#  ('spread', 'JJ'),
#  ('bleached', 'VBD'),
#  ('sewed', 'VBN'),
#  ('bags', 'NNS'),
#  ('thomas', 'VBP'),
#  ('awful', 'JJ'),
#  ('colour', 'JJ'),
#  ('month', 'NN'),
#  ('dewbleaching', 'VBG'),
#  ('work', 'NN'),
#  ('wonders', 'NNS'),
#  ('proudly', 'RB'),
#  ('giving', 'VBG'),
#  ('braided', 'VBN'),
#  ('rugs', 'NNS'),
#  ('shed', 'VBD'),
#  ('them—theyre', 'NN'),
#  ('oldfashioned', 'VBN'),
#  ('nobody', 'NN'),
#  ('hooked', 'VBD'),
#  ('mats', 'NNS'),
#  ('them—said', 'VBP'),
#  ('rather', 'RB'),
#  ('else', 'JJ'),
#  ('floors', 'NNS'),
#  ('11', 'CD'),
#  ('made', 'VBD'),
#  ('nicest', 'JJS'),
#  ('rags', 'NNS'),
#  ('stripes', 'NNS'),
#  ('company', 'NN'),
#  ('winters', 'NNS'),
#  ('make', 'VBP'),
#  ('stock', 'NN'),
#  ('jam', 'NN'),
#  ('closet', 'VBD'),
#  ('year', 'NN'),
#  ('trees', 'NNS'),
#  ('blossom', 'VBP'),
#  ('cut', 'JJ'),
#  ('spring', 'NN'),
#  ('white', 'JJ'),
#  ('crop', 'NN'),
#  ('plums', 'NNS'),
#  ('goodness', 'RB'),
#  ('ive', 'JJ'),
#  ('prayed', 'VBN'),
#  ('tone', 'NN'),
#  ('comfortably', 'RB'),
#  ('sure', 'JJ'),
#  ('prayers', 'NNS'),
#  ('availed', 'VBD'),
#  ('relief', 'NN'),
#  ('mean', 'JJ'),
#  ('kingsport', 'NN'),
#  ('rich', 'JJ'),
#  ('poor—at', 'NN'),
#  ('least', 'JJS'),
#  ('begin', 'JJ'),
#  ('hes', 'NNS'),
#  ('contentedly', 'RB'),
#  ('words', 'NNS'),
#  ('background', 'IN'),
#  ('childhood', 'NN'),
#  ('up—the', 'JJ'),
#  ('wilful', 'JJ'),
#  ('pride', 'NN'),
#  ('son', 'NN'),
#  ('evil', 'JJ'),
#  ('ancient', 'NN'),
#  ('bitterness', 'NN'),
#  ('almost', 'RB'),
#  ('frightened', 'VBD'),
#  ('gods', 'NNS'),
#  ('12', 'CD'),
#  ('superstition', 'NN'),
#  ('behold', 'NN'),
#  ('mortals', 'NNS'),
#  ('certain', 'JJ'),
#  ('human', 'JJ'),
#  ('beings', 'NNS'),
#  ('ilk', 'NN'),
#  ('descended', 'VBD'),
#  ('violet', 'NN'),
#  ('dusk', 'NN'),
#  ('proceeded', 'VBD'),
#  ('lay', 'NN'),
#  ('prick', 'NN'),
#  ('rainbow', 'NN'),
#  ('bubble', 'JJ'),
#  ('satisfaction', 'NN'),
#  ('particular', 'JJ'),
#  ('prize', 'NN'),
#  ('imagined', 'VBD'),
#  ('fatuated', 'VBN'),
#  ('salad', 'JJ'),
#  ('duty', 'NN'),
#  ('light', 'JJ'),
#  ('worthy', 'JJ'),
#  ('ladies', 'NNS'),
#  ('enemies', 'NNS'),
#  ('contrary', 'JJ'),
#  ('fond', 'NN'),
#  ('de', 'IN'),
#  ('fended', 'VBN'),
#  ('tacked', 'JJ'),
#  ('sistent', 'JJ'),
#  ('nature', 'NN'),
#  ('obliged', 'VBD'),
#  ('inglis—née', 'JJ'),
#  ('quote', 'JJ'),
#  ('daily', 'JJ'),
#  ('enterprise—came', 'NN'),
#  ('jasper', 'NN'),
#  ('bell', 'NN'),
#  ('milk', 'NN'),
#  ('kindness', 'NN'),
#  ('curdled', 'VBD'),
#  ('matrimonial', 'JJ'),
#  ('bicker', 'NN'),
#  ('ings', 'NNS'),
#  ('lines', 'NNS'),
#  ('fallen', 'VBN'),
#  ('places', 'NNS'),
#  ('spite', 'JJ'),
#  ('fact—as', 'JJ'),
#  ('say—', 'NN'),
#  ('wealth', 'NN'),
#  ('placid', 'NN'),
#  ('amiable', 'JJ'),
#  ('pinkcheeked', 'VBN'),
#  ('quartette', 'NN'),
#  ('sympathising', 'VBG'),
#  ('chum', 'NN'),
#  ('keenly', 'RB'),
#  ('dainty', 'NN'),
#  ('details', 'NNS'),
#  ('trousseau', 'VBP'),
#  ('rival', 'JJ'),
#  ('silken', 'NN'),
#  ('bejewelled', 'VBD'),
#  ('splendours', 'NNS'),
#  ('worth', 'JJ'),
#  ('13', 'CD'),
#  ('hurt', 'NN'),
#  ('anyones', 'NNS'),
#  ('feelings—which', 'RBR'),
#  ('negative', 'JJ'),
#  ('talent', 'NN'),
#  ('likewise', 'NN'),
#  ('rare', 'NN'),
#  ('enviable', 'JJ'),
#  ('back', 'RB'),
#  ('contriving', 'VBG'),
#  ('convey', 'NN'),
#  ('pression', 'NN'),
#  ('surprise', 'NN'),
#  ('blythes', 'NNS'),
#  ('generally', 'RB'),
#  ('word', 'NN'),
#  ('passed', 'VBD'),
#  ('happens', 'VBZ'),
#  ('see—youre', 'JJ'),
#  ('twentyfive', 'JJ'),
#  ('corner', 'NN'),
#  ('redheaded', 'VBD'),
#  ('helped', 'JJ'),
#  ('difficulties', 'NNS'),
#  ('steel', 'NN'),
#  ('reference', 'NN'),
#  ('hair', 'NN'),
#  ('conceded', 'VBD'),
#  ('is—so', 'NN'),
#  ('developed', 'VBD'),
#  ('red', 'JJ'),
#  ('trying', 'VBG'),
#  ('speaking', 'VBG'),
#  ('coldly', 'RB'),
#  ('doesnt', 'JJ'),
#  ('case', 'NN'),
#  ('turn', 'VB'),
#  ('engagement', 'JJ'),
#  ('wishes', 'NNS'),
#  ('freaks', 'JJ'),
#  ('position', 'NN'),
#  ('suitable', 'JJ'),
#  ('youll', 'NN'),
#  ('afraid', 'JJ'),
#  ('confidence', 'NN'),
#  ('gloomily', 'RB'),
#  ('shut', 'VBD'),
#  ('mouth', 'NN'),
#  ('tightly', 'RB'),
#  ('considered', 'VBN'),
#  ('conscience', 'NN'),
#  ('clear', 'JJ'),
#  ('14', 'CD'),
#  ('hat', 'WP'),
#  ('straggling', 'VBG'),
#  ('locks', 'NNS'),
#  ('feather', 'RB'),
#  ('belonged', 'VBD'),
#  ('type', 'NN'),
#  ('stringy', 'NN'),
#  ('neck', 'NN'),
#  ('surface', 'NN'),
#  ('bridal', 'NN'),
#  ('happi', 'VBD'),
#  ('temporarily', 'RB'),
#  ('shadowed', 'VBN'),
#  ('deeps', 'NNS'),
#  ('ness', 'JJ'),
#  ('thus', 'RB'),
#  ('disturbed', 'JJ'),
#  ('stings', 'NNS'),
#  ('mesdames', 'NNS'),
#  ('forgotten', 'VBP'),
#  ('ivory', 'JJ'),
#  ('columns', 'NN'),
#  ('later', 'RB'),
#  ('wandered', 'VBD'),
#  ('birches', 'NNS'),
#  ('brook', 'VBP'),
#  ('saplings', 'NNS'),
#  ('fairy', 'JJ'),
#  ('palace', 'NN'),
#  ('twilight', 'NN'),
#  ('stars', 'NNS'),
#  ('shadows', 'VBZ'),
#  ('talked', 'JJ'),
#  ('loverfashion', 'NN'),
#  ('together', 'RB'),
#  ('village', 'NN'),
#  ('nest', 'JJS'),
#  ('shore', 'NN'),
#  ('altogether', 'DT'),
#  ('situation', 'NN'),
#  ('point', 'NN'),
#  ('sunset', 'VBN'),
#  ('sanddunes', 'NNS'),
#  ('far', 'RB'),
#  ('away—the', 'JJ'),
#  ('seawinds', 'NNS'),
#  ('blow', 'VBP'),
#  ('sea', 'NN'),
#  ('spray', 'NN'),
#  ('drenches', 'VBZ'),
#  ('gilbertour', 'JJ'),
#  ('large', 'JJ'),
#  ('living', 'VBG'),
#  ('fireplace', 'NN'),
#  ('15', 'CD'),
#  ('dining', 'NN'),
#  ('office', 'NN'),
#  ('old—the', 'NN'),
#  ('oldest', 'JJS'),
#  ('repair', 'NN'),
#  ('fifteen', 'JJ'),
#  ('ago—', 'NN'),
#  ('shingled', 'VBD'),
#  ('plastered', 'VBN'),
#  ('refloored', 'JJ'),
#  ('built', 'VBN'),
#  ('understand', 'JJ'),
#  ('ro', 'NN'),
#  ('rented', 'VBD'),
#  ('mantic', 'JJ'),
#  ('story', 'NN'),
#  ('connected', 'VBN'),
#  ('building', 'NN'),
#  ('captain', 'NN'),
#  ('jim', 'NN'),
#  ('spin', 'NN'),
#  ('yarn', 'NN'),
#  ('revolving', 'VBG'),
#  ('twilights', 'NNS'),
#  ('keeper', 'NN'),
#  ('lighthouse', 'NN'),
#  ('magnificent', 'JJ'),
#  ('star', 'NN'),
#  ('windows', 'NNS'),
#  ('front', 'VBP'),
#  ('door', 'JJ'),
#  ('church', 'NN'),
#  ('lady', 'NN'),
#  ('miss', 'VBP'),
#  ('elizabeth', 'RB'),
#  ('russell', 'VBP'),
#  ('relatives', 'NNS'),
#  ('left', 'VBD'),
#  ('property', 'NN'),
#  ('trustees', 'NNS'),
#  ('despaired', 'VBD'),
#  ('mere', 'JJ'),
#  ('selling', 'NN'),
#  ('fashioned', 'VBD'),
#  ('it—for', 'NN'),
#  ('song', 'NN'),
#  ('bought', 'VBD'),
#  ...]
