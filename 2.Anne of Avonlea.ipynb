# %%
import os
DATA_DIR = 'txtfile'
fname = 'Anne of Avonlea nyp.33433074902507-1560363454.txt'
fname = os.path.join(DATA_DIR, fname)
with open(fname, encoding='utf-8') as f:
    text = f.read()
from string import punctuation
no_punct = ''.join([ch for ch in text if ch not in punctuation])
lower_text=no_punct.lower()

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(lower_text) 
  
clean_text = [w for w in word_tokens if not w in stop_words] 
  
clean_text = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        clean_text.append(w) 

stop=['“', '”','’','—']
filtered_word = [w for w in clean_text if not w in stop]

filtered_word = []

for w in clean_text: 
    if w not in stop: 
        filtered_word.append(w) 
        
print(filtered_word)
# Out:
# ['anne', 'avonlea', 'chapter', 'irate', 'neighbour', 'tall', 'slim', 'girl', 'halfpast', 'sixteen', 'serious', 'gray', 'eyes', 'hair', 'friends', 'called', 'auburn', 'sat', 'broad', 'red', 'sandstone', 'doorstep', 'prince', 'edward', 'island', 'farmhouse', 'one', 'ripe', 'afternoon', 'august', 'firmly', 'resolved', 'construe', 'many', 'lines', 'virgil', 'august', 'afternoon', 'blue', 'hazes', 'scarfing', 'harvest', 'slopes', 'little', 'winds', 'whispering', 'elfishly', 'poplars', 'dancing', 'splendour', 'red', 'poppies', 'outflaming', 'dark', 'coppice', 'young', 'firs', 'corner', 'cherry', 'orchard', 'fitter', 'dreams', 'dead', 'languages', 'virgil', 'soon', 'slipped', 'un', 'heeded', 'ground', 'anne', 'chin', 'propped', 'clasped', 'hands', 'eyes', 'splendid', 'mass', 'fluffy', 'clouds', 'heaping', 'mr', 'j', 'harrisons', 'house', 'like', 'great', 'white', 'mountain', 'far', 'away', 'delicious', 'world', 'certain', 'schoolteacher', 'wonderful', '1', 'work', 'shap', 'anne', 'oe', 'avonlea', 'ing', 'destinies', 'future', 'statesmen', 'inspiring', 'youthful', 'minds', 'hearts', 'high', 'lofty', 'ambi', 'tions', 'sure', 'came', 'harsh', 'facts', 'must', 'confessed', 'anne', 'seldom', 'seem', 'likely', 'much', 'promising', 'material', 'celebrities', 'avonlea', 'school', 'could', 'never', 'tell', 'might', 'happen', 'teacher', 'used', 'influence', 'good', 'anne', 'certain', 'rose', 'tinted', 'ideals', 'teacher', 'might', 'accomplish', 'went', 'right', 'way', 'midst', 'delightful', 'scene', 'forty', 'years', 'hence', 'famous', 'personage', 'exactly', 'famous', 'left', 'convenient', 'haziness', 'anne', 'thought', 'would', 'rather', 'nice', 'college', 'president', 'canadian', 'premier', 'bowing', 'low', 'wrinkled', 'hand', 'assuring', 'first', 'kindled', 'ambition', 'success', 'life', 'due', 'lessons', 'instilled', 'long', 'ago', 'avonlea', 'school', 'pleasant', 'vision', 'shattered', 'unpleasant', 'interrup', 'tion', 'demure', 'little', 'jersey', 'cow', 'came', 'scuttling', 'lane', 'five', 'seconds', 'later', 'arrived', 'mr', 'harrison', 'arrived', 'mild', 'term', 'describe', 'manner', 'irruption', 'yard', 'bounced', 'fence', 'without', 'waiting', 'open', 'gate', 'angrily', 'confronted', 'astonished', 'anne', 'risen', 'feet', 'stood', 'looking', 'bewilderment', 'mr', 'harrison', '8', 'new', 'right', 'irate', 'neighbour', 'hand', 'neighbour', 'never', 'met', 'although', 'seen', 'twice', 'early', 'april', 'anne', 'come', 'home', 'mr', 'robert', 'bell', 'queens', 'whose', 'farm', 'adjoined', 'cuthbert', 'place', 'west', 'sold', 'moved', 'farm', 'charlottetown', 'j', 'certain', 'mr', 'bought', 'harrison', 'whose', 'name', 'fact', 'new', 'brunswick', 'man', 'known', 'month', 'avonlea', 'reputation', 'odd', 'person', 'crank', 'mrs', 'rachel', 'lynde', 'said', 'mrs', 'rachel', 'outspoken', 'lady', 'may', 'already', 'made', 'acquaintance', 'member', 'mr', 'harrison', 'certainly', 'different', 'people', 'essential', 'characteristic', 'crank', 'everybody', 'knows', 'first', 'place', 'wanted', 'fools', 'women', 'kept', 'house', 'publicly', 'stated', 'around', 'diggings', 'feminine', 'avonlea', 'took', 'venge', 'grewsome', 'tales', 'related', 'house', 'hired', 'little', 'john', 'henry', 'carter', 'white', 'sands', 'john', 'henry', 'started', 'keeping', 'cooking', 'stories', 'one', 'thing', 'never', 'stated', 'time', 'meals', 'harrison', 'establishment', 'mr', 'harrison', 'got', 'bite', 'felt', 'hungry', 'john', 'henry', 'around', 'time', 'came', 'share', 'wait', 'mr', 'harrisons', 'next', 'hungry', 'spell', 'fully', 'averred', 'wasnt', 'john', 'henry', 'mourn', 'would', 'starved', 'death', 'got', 'home', 'sundays', 'got', 'good', '3', 'anne', 'avonlea', 'filling', 'mother', 'always', 'gave', 'take', 'back', 'basket', 'grub', 'monday', 'mornings', 'washing', 'dishes', 'mr', 'harrison', 'never', 'made', 'pretence', 'unless', 'rainy', 'sunday', 'came', 'went', 'work', 'washed', 'rainwater', 'hogshead', 'left', 'drain', 'dry', 'mr', 'harrison', 'asked ...

# %%
from collections import Counter
freq = Counter(filtered_text)
freq.most_common
# Out:
# <bound method Counter.most_common of Counter({'anne': 1121, 'said': 609, 'like': 295, 'mr': 291, 'would': 285, 'miss': 277, 'mrs': 276, 'never': 274, 'little': 262, 'avonlea': 253, 'marilla': 250, 'well': 250, 'im': 243, 'davy': 239, 'think': 238, 'dont': 237, 'one': 225, 'know': 220, 'diana': 213, 'see': 179, 'good': 178, 'day': 172, 'could': 170, 'go': 166, 'much': 162, 'old': 158, 'going': 153, 'oh': 145, 'came': 143, 'says': 143, 'come': 142, 'ever': 142, 'went': 139, 'things': 134, 'house': 134, 'harrison': 133, 'home': 131, 'thought': 130, 'always': 129, 'time': 128, 'lavendar': 128, 'tell': 127, 'get': 127, 'back': 126, 'must': 126, 'way': 123, 'ill': 120, 'paul': 118, 'eyes': 114, 'got': 114, 'told': 114, 'people': 113, 'thing': 113, 'cant': 112, 'say': 109, 'lynde': 103, 'right': 101, 'look': 99, 'made': 97, 'school': 96, 'id': 95, 'ive': 95, 'didnt': 93, 'want': 93, 'looked': 91, 'last': 90, 'two': 90, 'charlotta': 90, 'face': 89, 'white': 87, 'put': 87, 'long': 86, 'every': 85, 'girls': 85, 'really': 84, 'dora': 84, 'away': 83, 'make': 83, 'even': 82, 'road': 81, 'wont': 81, 'first': 79, 'something': 79, 'wouldnt': 79, 'since': 78, 'might': 77, 'green': 76, 'life': 76, 'mind': 76, 'better': 75, 'ing': 74, 'years': 73, 'teacher': 72, 'rather': 72, 'anything': 71, 'asked': 71, 'new': 70, 'sure': 70, 'man': 70, 'mother': 69, 'take': 69, 'isnt': 68, 'night': 68, 'thats': 68, 'garden': 68, 'world': 67, 'irving': 67, 'next': 66, 'jane': 66, 'fourth': 65, 'give': 65, 'theres': 65, 'love': 65, 'girl': 64, 'annes': 64, 'suppose': 64, 'course': 64, 'gilbert': 64, 'feel': 64, 'us': 64, 'shes': 63, 'tea': 63, 'nothing': 62, 'real': 62, 'may': 61, 'felt': 61, 'heard': 61, 'story': 60, 'awful': 60, 'knew': 59, 'found': 59, 'children': 59, 'shirley': 58, 'rachel': 57, 'pretty': 57, 'stone': 56, 'head': 56, 'let': 56, 'father': 56, 'believe': 55, 'coming': 55, 'young': 54, 'great': 54, 'heart': 54, 'place': 53, 'wasnt': 53, 'quite': 53, 'yes': 53, 'though': 52, 'boy': 52, 'hair': 51, 'couldnt': 51, 'yet': 51, 'room': 51, 'big': 51, 'doesnt': 50, 'mary': 50, 'evening': 50, 'kind': 50, 'beautiful': 50, 'many': 49, 'nice': 49, 'glad': 49, 'saw': 49, 'shall': 48, 'hes': 48, 'bed': 48, 'sweet': 48, 'maam': 48, 'around': 47, 'hand': 47, 'door': 47, 'mean': 46, 'best': 46, 'dear': 46, 'gables': 45, 'name': 45, 'done': 45, 'youll': 45, 'still': 45, 'left': 44, 'another': 44, 'twins': 44, 'bad': 44, 'chapter': 43, 'without': 43, 'took': 43, 'kitchen': 43, 'keep': 43, 'youre': 43, 'far': 42, 'wanted': 42, 'gone': 42, 'sitting': 42, 'till': 42, 'pye': 42, 'married': 42, 'set': 42, 'sloane': 42, 'window': 42, 'wrong': 42, 'golden': 41, 'looking': 41, 'perhaps': 41, 'uncle': 41, 'priscilla': 41, 'sat': 40, 'blue': 40, 'word': 40, 'help': 40, 'andrews': 40, 'grandma': 40, 'everybody': 39, 'woman': 39, 'hope': 39, 'along': 39, 'joe': 39, 'used': 38, 'hall': 38, 'ago': 38, 'cow': 38, 'boys': 38, 'talk': 38, 'gray': 37, 'seen': 37, 'nobody': 37, 'half': 37, 'three': 37, 'morning': 37, 'wife': 37, 'try': 37, 'dress': 37, 'seemed': 37, 'afternoon': 36, 'comes': 36, 'called': 36, 'soon': 36, 'kept': 36, 'ask': 36, 'else': 36, 'almost': 36, 'enough': 36, 'sorry': 36, 'youve': 36, 'today': 36, 'anthony': 36, 'seems': 36, 'ginger': 35, 'table': 35, 'everything': 34, 'st': 34, 'aint': 34, 'able': 34, 'lane': 33, 'poor': 33, 'live': 33, 'brought': 33, 'allan': 33, 'folks': 33, 'red': 32, 'hands': 32, 'although': 32, 'bell': 32, 'shed': 32, 'moment': 32, 'cause': 32, 'child': 32, 'getting': 32, 'woods': 32, 'gave': 31, 'find': 31, 'matter': 31, 'making': 31, 'call': 31, 'eat': 31, 'dinner': 31, 'spring': 30, 'impression': 30, 'seem': 30, 'across': 30, 'hear': 30, 'wish': 30, 'year': 30, 'theyre': 30, 'hadnt': 30, 'society': 30, 'lovely': 30, 'times': 30, 'heaven': 30, 'letter': 30, 'whole': 29, 'hard': 29, 'trouble': 29, 'true': 29, 'carmody': 29, 'thinking': 29, 'turned': 29, 'cake': 29, 'sit': 29, 'milty': 29, 'full': 28, 'dark': 28, 'person': 28, 'lady': ...

# %%
from collections import Counter
freq = Counter(filtered_text)
freq.most_common
# Out:
# <bound method Counter.most_common of Counter({'anne': 1121, 'said': 609, 'like': 295, 'mr': 291, 'would': 285, 'miss': 277, 'mrs': 276, 'never': 274, 'little': 262, 'avonlea': 253, 'marilla': 250, 'well': 250, 'im': 243, 'davy': 239, 'think': 238, 'dont': 237, 'one': 225, 'know': 220, 'diana': 213, 'see': 179, 'good': 178, 'day': 172, 'could': 170, 'go': 166, 'much': 162, 'old': 158, 'going': 153, 'oh': 145, 'came': 143, 'says': 143, 'come': 142, 'ever': 142, 'went': 139, 'things': 134, 'house': 134, 'harrison': 133, 'home': 131, 'thought': 130, 'always': 129, 'time': 128, 'lavendar': 128, 'tell': 127, 'get': 127, 'back': 126, 'must': 126, 'way': 123, 'ill': 120, 'paul': 118, 'eyes': 114, 'got': 114, 'told': 114, 'people': 113, 'thing': 113, 'cant': 112, 'say': 109, 'lynde': 103, 'right': 101, 'look': 99, 'made': 97, 'school': 96, 'id': 95, 'ive': 95, 'didnt': 93, 'want': 93, 'looked': 91, 'last': 90, 'two': 90, 'charlotta': 90, 'face': 89, 'white': 87, 'put': 87, 'long': 86, 'every': 85, 'girls': 85, 'really': 84, 'dora': 84, 'away': 83, 'make': 83, 'even': 82, 'road': 81, 'wont': 81, 'first': 79, 'something': 79, 'wouldnt': 79, 'since': 78, 'might': 77, 'green': 76, 'life': 76, 'mind': 76, 'better': 75, 'ing': 74, 'years': 73, 'teacher': 72, 'rather': 72, 'anything': 71, 'asked': 71, 'new': 70, 'sure': 70, 'man': 70, 'mother': 69, 'take': 69, 'isnt': 68, 'night': 68, 'thats': 68, 'garden': 68, 'world': 67, 'irving': 67, 'next': 66, 'jane': 66, 'fourth': 65, 'give': 65, 'theres': 65, 'love': 65, 'girl': 64, 'annes': 64, 'suppose': 64, 'course': 64, 'gilbert': 64, 'feel': 64, 'us': 64, 'shes': 63, 'tea': 63, 'nothing': 62, 'real': 62, 'may': 61, 'felt': 61, 'heard': 61, 'story': 60, 'awful': 60, 'knew': 59, 'found': 59, 'children': 59, 'shirley': 58, 'rachel': 57, 'pretty': 57, 'stone': 56, 'head': 56, 'let': 56, 'father': 56, 'believe': 55, 'coming': 55, 'young': 54, 'great': 54, 'heart': 54, 'place': 53, 'wasnt': 53, 'quite': 53, 'yes': 53, 'though': 52, 'boy': 52, 'hair': 51, 'couldnt': 51, 'yet': 51, 'room': 51, 'big': 51, 'doesnt': 50, 'mary': 50, 'evening': 50, 'kind': 50, 'beautiful': 50, 'many': 49, 'nice': 49, 'glad': 49, 'saw': 49, 'shall': 48, 'hes': 48, 'bed': 48, 'sweet': 48, 'maam': 48, 'around': 47, 'hand': 47, 'door': 47, 'mean': 46, 'best': 46, 'dear': 46, 'gables': 45, 'name': 45, 'done': 45, 'youll': 45, 'still': 45, 'left': 44, 'another': 44, 'twins': 44, 'bad': 44, 'chapter': 43, 'without': 43, 'took': 43, 'kitchen': 43, 'keep': 43, 'youre': 43, 'far': 42, 'wanted': 42, 'gone': 42, 'sitting': 42, 'till': 42, 'pye': 42, 'married': 42, 'set': 42, 'sloane': 42, 'window': 42, 'wrong': 42, 'golden': 41, 'looking': 41, 'perhaps': 41, 'uncle': 41, 'priscilla': 41, 'sat': 40, 'blue': 40, 'word': 40, 'help': 40, 'andrews': 40, 'grandma': 40, 'everybody': 39, 'woman': 39, 'hope': 39, 'along': 39, 'joe': 39, 'used': 38, 'hall': 38, 'ago': 38, 'cow': 38, 'boys': 38, 'talk': 38, 'gray': 37, 'seen': 37, 'nobody': 37, 'half': 37, 'three': 37, 'morning': 37, 'wife': 37, 'try': 37, 'dress': 37, 'seemed': 37, 'afternoon': 36, 'comes': 36, 'called': 36, 'soon': 36, 'kept': 36, 'ask': 36, 'else': 36, 'almost': 36, 'enough': 36, 'sorry': 36, 'youve': 36, 'today': 36, 'anthony': 36, 'seems': 36, 'ginger': 35, 'table': 35, 'everything': 34, 'st': 34, 'aint': 34, 'able': 34, 'lane': 33, 'poor': 33, 'live': 33, 'brought': 33, 'allan': 33, 'folks': 33, 'red': 32, 'hands': 32, 'although': 32, 'bell': 32, 'shed': 32, 'moment': 32, 'cause': 32, 'child': 32, 'getting': 32, 'woods': 32, 'gave': 31, 'find': 31, 'matter': 31, 'making': 31, 'call': 31, 'eat': 31, 'dinner': 31, 'spring': 30, 'impression': 30, 'seem': 30, 'across': 30, 'hear': 30, 'wish': 30, 'year': 30, 'theyre': 30, 'hadnt': 30, 'society': 30, 'lovely': 30, 'times': 30, 'heaven': 30, 'letter': 30, 'whole': 29, 'hard': 29, 'trouble': 29, 'true': 29, 'carmody': 29, 'thinking': 29, 'turned': 29, 'cake': 29, 'sit': 29, 'milty': 29, 'full': 28, 'dark': 28, 'person': 28, 'lady': ...

# %%
from nltk.probability import FreqDist
Fdist = FreqDist(filtered_text)
print(Fdist)
# Out:
# <FreqDist with 44 samples and 313663 outcomes>

# %%
from matplotlib import pyplot as plt
import nltk
freqdist = nltk.FreqDist(filtered_word)
plt.figure(figsize=(16,5))
freqdist.plot(50)
plt.show()

# %%
Fdist['anne']
# Out:
# 1109

# %%
Fdist['anne']/len(word_tokens)
# Out:
# 0.011859313678312106

# %%
Fdist.plot(50, cumulative=True)

# %%
filtered_text=' '.join(filtered_word)

# %%
import os
os.path
# !pip install wordcloud
import wordcloud
from wordcloud import WordCloud
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
wordcloud = WordCloud(max_words=150,background_color="white").generate(filtered_text)
plt.figure(figsize=(16,12))
# plot wordcloud in matplotlib
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Requirement already satisfied: wordcloud in /Applications/anaconda3/lib/python3.7/site-packages (1.5.0)
# Requirement already satisfied: pillow in /Applications/anaconda3/lib/python3.7/site-packages (from wordcloud) (5.4.1)
# Requirement already satisfied: numpy>=1.6.1 in /Applications/anaconda3/lib/python3.7/site-packages (from wordcloud) (1.16.2)

# %%
wordcloud.to_file("txtfile/Anne of Avonlea.png")

# %%
import nltk
freqdist = nltk.FreqDist(filtered_text)
plt.figure(figsize=(16,5))
freqdist.plot(50)

# %%
lexical_diversity = len(set(word_tokens)) / len(word_tokens)
lexical_diversity
# Out:
# 0.09472479762172105

# %%
len(set(word_tokens))
# Out:
# 8858

# %%
len(word_tokens)
# Out:
# 93513

# %%
[len(w) for w in word_tokens]
# Out:
# [4,
#  2,
#  7,
#  7,
#  1,
#  2,
#  5,
#  9,
#  1,
#  4,
#  4,
#  4,
#  8,
#  7,
#  4,
#  7,
#  4,
#  4,
#  3,
#  4,
#  5,
#  3,
#  7,
#  6,
#  6,
#  3,
#  3,
#  4,
#  2,
#  3,
#  5,
#  3,
#  9,
#  8,
#  2,
#  1,
#  6,
#  6,
#  6,
#  9,
#  3,
#  4,
#  9,
#  2,
#  6,
#  6,
#  8,
#  2,
#  8,
#  2,
#  4,
#  5,
#  2,
#  6,
#  3,
#  2,
#  6,
#  9,
#  4,
#  4,
#  5,
#  8,
#  3,
#  7,
#  6,
#  6,
#  5,
#  10,
#  8,
#  2,
#  3,
#  7,
#  3,
#  1,
#  7,
#  9,
#  2,
#  3,
#  7,
#  10,
#  7,
#  3,
#  4,
#  7,
#  2,
#  5,
#  4,
#  2,
#  1,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  6,
#  3,
#  6,
#  4,
#  4,
#  9,
#  3,
#  6,
#  4,
#  7,
#  2,
#  6,
#  2,
#  3,
#  6,
#  3,
#  4,
#  3,
#  4,
#  7,
#  2,
#  3,
#  7,
#  5,
#  3,
#  3,
#  4,
#  2,
#  3,
#  8,
#  4,
#  2,
#  6,
#  6,
#  4,
#  4,
#  7,
#  2,
#  4,
#  4,
#  2,
#  1,
#  1,
#  9,
#  5,
#  4,
#  1,
#  5,
#  5,
#  8,
#  3,
#  3,
#  4,
#  2,
#  1,
#  9,
#  5,
#  5,
#  1,
#  7,
#  13,
#  3,
#  5,
#  1,
#  9,
#  1,
#  4,
#  4,
#  4,
#  2,
#  7,
#  3,
#  3,
#  9,
#  2,
#  6,
#  9,
#  3,
#  9,
#  8,
#  5,
#  3,
#  6,
#  4,
#  4,
#  3,
#  5,
#  4,
#  5,
#  2,
#  2,
#  4,
#  2,
#  3,
#  4,
#  4,
#  2,
#  5,
#  5,
#  5,
#  2,
#  4,
#  2,
#  9,
#  4,
#  6,
#  3,
#  5,
#  3,
#  2,
#  3,
#  3,
#  4,
#  6,
#  4,
#  5,
#  3,
#  4,
#  9,
#  8,
#  3,
#  11,
#  2,
#  7,
#  6,
#  3,
#  2,
#  3,
#  3,
#  5,
#  5,
#  4,
#  4,
#  5,
#  6,
#  2,
#  1,
#  7,
#  4,
#  3,
#  9,
#  3,
#  4,
#  4,
#  3,
#  7,
#  4,
#  2,
#  6,
#  6,
#  2,
#  4,
#  1,
#  7,
#  5,
#  10,
#  3,
#  4,
#  4,
#  3,
#  5,
#  3,
#  5,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  5,
#  2,
#  1,
#  10,
#  5,
#  5,
#  5,
#  5,
#  4,
#  1,
#  6,
#  9,
#  4,
#  7,
#  4,
#  2,
#  3,
#  2,
#  2,
#  6,
#  3,
#  3,
#  4,
#  2,
#  10,
#  8,
#  3,
#  4,
#  7,
#  2,
#  5,
#  2,
#  6,
#  4,
#  2,
#  4,
#  3,
#  1,
#  7,
#  9,
#  2,
#  1,
#  8,
#  7,
#  6,
#  3,
#  4,
#  3,
#  8,
#  4,
#  3,
#  8,
#  3,
#  4,
#  2,
#  3,
#  3,
#  3,
#  3,
#  5,
#  7,
#  3,
#  8,
#  3,
#  4,
#  3,
#  3,
#  7,
#  2,
#  4,
#  3,
#  3,
#  2,
#  3,
#  7,
#  3,
#  3,
#  9,
#  2,
#  4,
#  3,
#  2,
#  7,
#  6,
#  4,
#  8,
#  6,
#  3,
#  9,
#  2,
#  1,
#  4,
#  10,
#  8,
#  4,
#  1,
#  6,
#  6,
#  6,
#  3,
#  4,
#  9,
#  4,
#  3,
#  4,
#  3,
#  4,
#  7,
#  5,
#  2,
#  7,
#  2,
#  8,
#  7,
#  2,
#  3,
#  3,
#  4,
#  1,
#  4,
#  2,
#  8,
#  3,
#  6,
#  2,
#  3,
#  9,
#  4,
#  3,
#  4,
#  2,
#  7,
#  4,
#  3,
#  5,
#  7,
#  7,
#  2,
#  4,
#  3,
#  4,
#  3,
#  7,
#  10,
#  10,
#  4,
#  3,
#  3,
#  5,
#  2,
#  3,
#  4,
#  3,
#  5,
#  7,
#  2,
#  3,
#  2,
#  4,
#  12,
#  2,
#  8,
#  1,
#  3,
#  5,
#  3,
#  5,
#  2,
#  5,
#  9,
#  4,
#  9,
#  3,
#  3,
#  3,
#  5,
#  3,
#  3,
#  6,
#  8,
#  3,
#  3,
#  4,
#  3,
#  4,
#  2,
#  5,
#  2,
#  5,
#  5,
#  6,
#  4,
#  3,
#  4,
#  4,
#  4,
#  2,
#  6,
#  4,
#  6,
#  5,
#  4,
#  8,
#  3,
#  8,
#  5,
#  2,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  5,
#  3,
#  4,
#  2,
#  13,
#  1,
#  7,
#  2,
#  3,
#  4,
#  6,
#  2,
#  1,
#  1,
#  8,
#  5,
#  4,
#  3,
#  3,
#  4,
#  4,
#  2,
#  3,
#  1,
#  3,
#  9,
#  3,
#  4,
#  3,
#  4,
#  3,
#  5,
#  5,
#  3,
#  3,
#  6,
#  2,
#  3,
#  4,
#  1,
#  5,
#  2,
#  7,
#  2,
#  3,
#  3,
#  3,
#  10,
#  2,
#  5,
#  2,
#  3,
#  6,
#  1,
#  5,
#  3,
#  6,
#  5,
#  4,
#  3,
#  6,
#  3,
#  2,
#  9,
#  4,
#  2,
#  5,
#  2,
#  3,
#  3,
#  3,
#  4,
#  7,
#  4,
#  3,
#  12,
#  4,
#  2,
#  6,
#  2,
#  8,
#  3,
#  9,
#  9,
#  4,
#  5,
#  6,
#  2,
#  3,
#  4,
#  2,
#  3,
#  9,
#  14,
#  1,
#  5,
#  2,
#  9,
#  5,
#  2,
#  3,
#  5,
#  5,
#  3,
#  7,
#  3,
#  3,
#  6,
#  2,
#  5,
#  2,
#  5,
#  2,
#  4,
#  5,
#  8,
#  6,
#  4,
#  2,
#  6,
#  3,
#  8,
#  8,
#  7,
#  4,
#  3,
#  2,
#  5,
#  2,
#  3,
#  8,
#  5,
#  2,
#  7,
#  5,
#  3,
#  5,
#  2,
#  3,
#  5,
#  6,
#  4,
#  5,
#  6,
#  2,
#  5,
#  5,
#  3,
#  4,
#  5,
#  7,
#  3,
#  7,
#  3,
#  7,
#  7,
#  3,
#  3,
#  5,
#  5,
#  3,
#  5,
#  3,
#  6,
#  4,
#  3,
#  5,
#  2,
#  3,
#  8,
#  13,
#  2,
#  8,
#  3,
#  1,
#  4,
#  4,
#  2,
#  4,
#  6,
#  3,
#  2,
#  4,
#  5,
#  4,
#  6,
#  2,
#  3,
#  4,
#  2,
#  4,
#  2,
#  3,
#  1,
#  5,
#  3,
#  2,
#  2,
#  4,
#  3,
#  2,
#  3,
#  2,
#  4,
#  5,
#  2,
#  9,
#  4,
#  6,
#  5,
#  5,
#  7,
#  4,
#  2,
#  5,
#  4,
#  5,
#  5,
#  2,
#  5,
#  4,
#  7,
#  2,
#  5,
#  2,
#  4,
#  2,
#  3,
#  4,
#  2,
#  7,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  2,
#  7,
#  7,
#  2,
#  3,
#  4,
#  3,
#  6,
#  6,
#  4,
#  3,
#  1,
#  2,
#  4,
#  4,
#  4,
#  3,
#  2,
#  6,
#  2,
#  4,
#  6,
#  8,
#  2,
#  3,
#  7,
#  6,
#  2,
#  8,
#  5,
#  4,
#  3,
#  8,
#  2,
#  5,
#  2,
#  6,
#  1,
#  5,
#  6,
#  4,
#  4,
#  2,
#  4,
#  2,
#  4,
#  3,
#  6,
#  4,
#  3,
#  2,
#  4,
#  2,
#  3,
#  9,
#  8,
#  3,
#  4,
#  4,
#  2,
#  5,
#  3,
#  5,
#  2,
#  8,
#  3,
#  5,
#  2,
#  9,
#  2,
#  3,
#  3,
#  4,
#  2,
#  3,
#  5,
#  2,
#  6,
#  6,
#  2,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  7,
#  5,
#  4,
#  2,
#  3,
#  3,
#  2,
#  3,
#  9,
#  5,
#  2,
#  2,
#  5,
#  3,
#  4,
#  3,
#  7,
#  2,
#  6,
#  1,
#  3,
#  2,
#  1,
#  4,
#  5,
#  4,
#  2,
#  3,
#  3,
#  1,
#  12,
#  2,
#  8,
#  3,
#  12,
#  2,
#  3,
#  3,
#  6,
#  2,
#  3,
#  5,
#  4,
#  3,
#  5,
#  4,
#  4,
#  8,
#  3,
#  3,
#  5,
#  2,
#  5,
#  7,
#  2,
#  7,
#  4,
#  8,
#  4,
#  2,
#  4,
#  2,
#  3,
#  3,
#  10,
#  10,
#  2,
#  1,
#  7,
#  3,
#  14,
#  4,
#  2,
#  4,
#  9,
#  2,
#  3,
#  6,
#  3,
#  7,
#  4,
#  3,
#  4,
#  2,
#  3,
#  1,
#  5,
#  4,
#  3,
#  6,
#  4,
#  3,
#  4,
#  2,
#  3,
#  5,
#  3,
#  2,
#  5,
#  4,
#  6,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  2,
#  3,
#  5,
#  2,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  4,
#  5,
#  3,
#  3,
#  8,
#  3,
#  7,
#  5,
#  5,
#  6,
#  3,
#  3,
#  5,
#  4,
#  7,
#  8,
#  11,
#  3,
#  2,
#  6,
#  2,
#  3,
#  5,
#  3,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  4,
#  2,
#  2,
#  6,
#  6,
#  2,
#  7,
#  2,
#  8,
#  4,
#  1,
#  6,
#  6,
#  6,
#  6,
#  2,
#  7,
#  3,
#  4,
#  4,
#  1,
#  6,
#  6,
#  12,
#  4,
#  10,
#  3,
#  10,
#  11,
#  3,
#  4,
#  1,
#  6,
#  2,
#  6,
#  3,
#  4,
#  4,
#  2,
#  5,
#  9,
#  2,
#  4,
#  2,
#  5,
#  7,
#  4,
#  3,
#  5,
#  3,
#  4,
#  2,
#  ...]

# %%
fdist = FreqDist(len(w) for w in word_tokens) 
print(fdist)
fdist
# Out:
# <FreqDist with 19 samples and 93513 outcomes>
# FreqDist({3: 21713, 4: 20742, 2: 15413, 5: 10924, 6: 7553, 7: 6025, 1: 4085, 8: 3077, 9: 2017, 10: 1019, ...})

# %%
fdist.most_common()
# Out:
# [(3, 21713),
#  (4, 20742),
#  (2, 15413),
#  (5, 10924),
#  (6, 7553),
#  (7, 6025),
#  (1, 4085),
#  (8, 3077),
#  (9, 2017),
#  (10, 1019),
#  (11, 505),
#  (12, 268),
#  (13, 105),
#  (14, 45),
#  (15, 12),
#  (16, 6),
#  (18, 2),
#  (32, 1),
#  (17, 1)]

# %%
fdist.freq(fdist.max())
# Out:
# 0.23219231550693487

# %%
len(text.split())
# Out:
# 97950

# %%
import nltk
from nltk import pos_tag
nltk.pos_tag(freq)
# Out:
# [('anne', 'JJ'),
#  ('avonlea', 'NN'),
#  ('lm', 'NN'),
#  ('montgomery', 'NN'),
#  ('frontispiece', 'NN'),
#  ('cover', 'VB'),
#  ('colour', 'NN'),
#  ('george', 'NN'),
#  ('gibbs', 'NN'),
#  ('l', 'NN'),
#  ('lucy', 'NN'),
#  ('maud', 'VBD'),
#  ('18741942', 'CD'),
#  ('new', 'JJ'),
#  ('york', 'NN'),
#  ('grosset', 'NN'),
#  ('dunlap', 'NN'),
#  ('1917', 'CD'),
#  ('httphdlhandlenet2027nyp33433074902507', 'NN'),
#  ('public', 'JJ'),
#  ('domain', 'NN'),
#  ('googledigitized', 'VBD'),
#  ('httpwwwhathitrustorgaccessusepdgoogle', 'NN'),
#  ('determined', 'VBN'),
#  ('work', 'NN'),
#  ('meaning', 'VBG'),
#  ('subject', 'JJ'),
#  ('copyright', 'NN'),
#  ('users', 'NNS'),
#  ('free', 'VBP'),
#  ('copy', 'NN'),
#  ('use', 'NN'),
#  ('redistribute', 'JJ'),
#  ('part', 'NN'),
#  ('whole', 'RBR'),
#  ('possible', 'JJ'),
#  ('current', 'JJ'),
#  ('holders', 'NNS'),
#  ('heirs', 'VBP'),
#  ('estate', 'NN'),
#  ('authors', 'NNS'),
#  ('individual', 'JJ'),
#  ('portions', 'NNS'),
#  ('illustrations', 'NNS'),
#  ('photographs', 'VBP'),
#  ('assert', 'JJ'),
#  ('copyrights', 'NNS'),
#  ('depending', 'VBG'),
#  ('nature', 'NN'),
#  ('subsequent', 'NN'),
#  ('made', 'VBD'),
#  ('additional', 'JJ'),
#  ('rights', 'NNS'),
#  ('may', 'MD'),
#  ('need', 'VB'),
#  ('obtained', 'VBN'),
#  ('independently', 'RB'),
#  ('anything', 'NN'),
#  ('address', 'JJ'),
#  ('digital', 'JJ'),
#  ('images', 'NNS'),
#  ('ocr', 'VBP'),
#  ('produced', 'VBN'),
#  ('google', 'JJ'),
#  ('inc', 'NN'),
#  ('indicated', 'VBD'),
#  ('watermark', 'JJ'),
#  ('page', 'NN'),
#  ('pageturner', 'NN'),
#  ('requests', 'NNS'),
#  ('rehosted', 'VBD'),
#  ('redistributed', 'VBN'),
#  ('used', 'VBN'),
#  ('commercially', 'RB'),
#  ('provided', 'VBN'),
#  ('educational', 'JJ'),
#  ('scholarly', 'JJ'),
#  ('noncommercial', 'JJ'),
#  ('purposes', 'NNS'),
#  ('3', 'CD'),
#  ('3433', 'CD'),
#  ('07490250', 'CD'),
#  ('7', 'CD'),
#  ('•—', 'NN'),
#  ('jl', 'NN'),
#  ('9', 'CD'),
#  ('novels', 'NNS'),
#  ('one', 'CD'),
#  ('volume', 'NN'),
#  ('cloth', 'CC'),
#  ('decorative', 'JJ'),
#  ('illustrated', 'JJ'),
#  ('net', 'JJ'),
#  ('135', 'CD'),
#  ('carriage', 'NN'),
#  ('paid', 'VBD'),
#  ('150', 'CD'),
#  ('four', 'CD'),
#  ('books', 'NNS'),
#  ('green', 'JJ'),
#  ('gables', 'NNS'),
#  ('island', 'VBP'),
#  ('chronicles', 'NNS'),
#  ('kilmeny', 'VB'),
#  ('orchard', 'RB'),
#  ('story', 'NN'),
#  ('girl', 'JJ'),
#  ('golden', 'JJ'),
#  ('road', 'NN'),
#  ('company', 'NN'),
#  ('53', 'CD'),
#  ('beacon', 'NN'),
#  ('street', 'NN'),
#  ('boston', 'JJ'),
#  ('mass', 'NN'),
#  ('g', 'NN'),
#  ('»', 'NNP'),
#  ('«', 'NNP'),
#  ('lierak', 'VBZ'),
#  ('aston', 'NN'),
#  ('frt', 'NN'),
#  ('u', 'JJ'),
#  ('nt', 'JJ'),
#  ('••', 'NN'),
#  ('f', 'NN'),
#  ('k', 'NN'),
#  ('wyn', 'WRB'),
#  ('j', 'NN'),
#  ('siiikley', 'NN'),
#  ('painting', 'VBG'),
#  ('author', 'NN'),
#  ('vne', 'NN'),
#  ('••••', 'NNP'),
#  ('i7', 'NN'),
#  ('ifpce', 'NN'),
#  ('clvkk', 'NN'),
#  ('e', 'NN'),
#  ('r', 'NN'),
#  ('h', 'NN'),
#  ('b', 'NN'),
#  ('•', 'NNP'),
#  ('••••••', 'NNP'),
#  ('c', 'VBD'),
#  ('ul', 'JJ'),
#  ('ways', 'NNS'),
#  ('duty', 'NN'),
#  ('stiff', 'JJ'),
#  ('line', 'NN'),
#  ('hfe', 'NN'),
#  ('hr', 'NN'),
#  ('wg', 'NN'),
#  ('curves', 'VBZ'),
#  ('beauty—', 'JJ'),
#  ('whltltr', 'NN'),
#  ('ng', 'NN'),
#  ('hossom', 'NN'),
#  ('walks', 'NNS'),
#  ('rosset', 'VBP'),
#  ('dunlat', 'JJ'),
#  ('plblishers', 'NNS'),
#  ('shirley', 'VBP'),
#  ('flowers', 'NNS'),
#  ('spring', 'VBG'),
#  ('blossom', 'NN'),
#  ('careful', 'JJ'),
#  ('hard', 'JJ'),
#  ('lines', 'NNS'),
#  ('life', 'NN'),
#  ('flowing', 'VBG'),
#  ('beauty', 'NN'),
#  ('—', 'NNP'),
#  ('whlttta', 'NN'),
#  ('publishers', 'NNS'),
#  ('1', 'CD'),
#  ('2892', 'CD'),
#  ('1909', 'CD'),
#  ('compact', 'NN'),
#  ('incorporated', 'VBN'),
#  ('entered', 'VBD'),
#  ('stationers', 'NNS'),
#  ('hall', 'JJ'),
#  ('london', 'RB'),
#  ('reserved', 'VBD'),
#  ('first', 'JJ'),
#  ('impression', 'NN'),
#  ('september', 'VB'),
#  ('second', 'JJ'),
#  ('third', 'JJ'),
#  ('fourth', 'JJ'),
#  ('october', 'NNP'),
#  ('fifth', 'JJ'),
#  ('november', 'RB'),
#  ('sixth', 'JJ'),
#  ('december', 'NNP'),
#  ('seventh', 'JJ'),
#  ('eighth', 'VBD'),
#  ('march', 'NN'),
#  ('1910', 'CD'),
#  ('ninth', 'JJ'),
#  ('july', 'RB'),
#  ('tenth', 'JJ'),
#  ('eleventh', 'JJ'),
#  ('twelfth', 'JJ'),
#  ('thirteenth', 'NN'),
#  ('april', 'NN'),
#  ('1911', 'CD'),
#  ('fourteenth', 'NN'),
#  ('august', 'JJ'),
#  ('fifteenth', 'NN'),
#  ('sixteenth', 'NN'),
#  ('1912', 'CD'),
#  ('seventeenth', 'NN'),
#  ('1913', 'CD'),
#  ('eighteenth', 'JJ'),
#  ('nineteenth', 'JJ'),
#  ('twentieth', 'NN'),
#  ('1914', 'CD'),
#  ('twentyfirst', 'JJ'),
#  ('19', 'CD'),
#  ('twentysecond', 'NN'),
#  ('june', 'NN'),
#  ('1915', 'CD'),
#  ('twentythird', 'NN'),
#  ('twentyfourth', 'NN'),
#  ('1916', 'CD'),
#  ('twentyfifth', 'NN'),
#  ('twentysixth', 'JJ'),
#  ('colonial', 'JJ'),
#  ('press', 'NN'),
#  ('simonds', 'NNS'),
#  ('co', 'VBP'),
#  ('v', 'RB'),
#  ('8', 'CD'),
#  ('former', 'JJ'),
#  ('teacher', 'NN'),
#  ('fattie', 'NN'),
#  ('sortjon', 'NN'),
#  ('grateful', 'JJ'),
#  ('sympathy', 'JJ'),
#  ('smttb', 'NN'),
#  ('remembrance', 'NN'),
#  ('encouragement', 'NN'),
#  ('contents', 'NNS'),
#  ('chapter', 'NN'),
#  ('ii', 'VBP'),
#  ('iii', 'NN'),
#  ('iv', 'NN'),
#  ('vi', 'NN'),
#  ('irate', 'VB'),
#  ('neighbour', 'JJ'),
#  ('selling', 'NN'),
#  ('haste', 'NN'),
#  ('repenting', 'VBG'),
#  ('leisure', 'NN'),
#  ('mr', 'FW'),
#  ('harrison', 'NN'),
#  ('home', 'NN'),
#  ('x', 'NNP'),
#  ('sorts', 'VBZ'),
#  ('conditions', 'NNS'),
#  ('men', 'NNS'),
#  ('question', 'VBP'),
#  ('xiii', 'JJ'),
#  ('xiv', 'NNP'),
#  ('xv', 'NNP'),
#  ('xvi', 'NNP'),
#  ('xvii', 'NNP'),
#  ('xviii', 'NNP'),
#  ('xix', 'NNP'),
#  ('xx', 'NNP'),
#  ('xxi', 'NNP'),
#  ('xxii', 'NNP'),
#  ('xxiii', 'VBD'),
#  ('24', 'CD'),
#  ('34', 'CD'),
#  ('4i', 'CD'),
#  ('davy', 'JJ'),
#  ('search', 'NN'),
#  ('sensation', 'NN'),
#  ('xi', 'NNP'),
#  ('xii', 'VBZ'),
#  ('15', 'CD'),
#  ('full', 'JJ'),
#  ('fledged', 'VBN'),
#  ('schoolmaam', 'NN'),
#  ('vii', 'NN'),
#  ('viii', 'JJ'),
#  ('ix', 'JJ'),
#  ('day', 'NN'),
#  ('jonah', 'NN'),
#  ('picnic', 'NN'),
#  ('danger', 'NN'),
#  ('averted', 'VBD'),
#  ('beginning', 'VBG'),
#  ('vacation', 'NN'),
#  ('substance', 'NN'),
#  ('things', 'NNS'),
#  ('hoped', 'VBD'),
#  ('accidents', 'NNS'),
#  ('adventure', 'JJ'),
#  ('tory', 'JJ'),
#  ('way', 'NN'),
#  ('often', 'RB'),
#  ('happens', 'VBZ'),
#  ('miss', 'JJ'),
#  ('lavendars', 'NNS'),
#  ('romance', 'VBP'),
#  ('5i', 'CD'),
#  ('66', 'CD'),
#  ('74', 'CD'),
#  ('86', 'CD'),
#  ('95', 'CD'),
#  ('109', 'CD'),
#  ('122', 'CD'),
#  ('132', 'CD'),
#  ('146', 'CD'),
#  ('162', 'CD'),
#  ('173', 'CD'),
#  ('182', 'CD'),
#  ('197', 'CD'),
#  ('210', 'CD'),
#  ('225', 'CD'),
#  ('236', 'CD'),
#  ('254', 'CD'),
#  ('■', 'JJ'),
#  ('261', 'CD'),
#  ('cuim', 'NN'),
#  ('xxiv', 'NNP'),
#  ('xxv', 'NNP'),
#  ('xxvi', 'NNP'),
#  ('xxvii', 'NNP'),
#  ('xxviii', 'NNP'),
#  ('xxix', 'NNP'),
#  ('xxx', 'NNP'),
#  ('prophet', 'VBD'),
#  ('country', 'NN'),
#  ('271', 'CD'),
#  ('scandal', 'NN'),
#  ('around', 'RB'),
#  ('bend', 'JJ'),
#  ('afternoon', 'NN'),
#  ('stone', 'NN'),
#  ('house', 'NN'),
#  ('prince', 'NN'),
#  ('comes', 'VBZ'),
#  ('back', 'RB'),
#  ('enchanted', 'JJ'),
#  ('palace', 'NN'),
#  ('poetry', 'NN'),
#  ('prose', 'VBD'),
#  ('wedding', 'VBG'),
#  ('283', 'CD'),
#  ('300', 'CD'),
#  ('315', 'CD'),
#  ('332', 'CD'),
#  ('347', 'CD'),
#  ('357', 'CD'),
#  ('tall', 'JJ'),
#  ('slim', 'JJ'),
#  ('halfpast', 'NN'),
#  ('sixteen', 'JJ'),
#  ('serious', 'JJ'),
#  ('gray', 'JJ'),
#  ('eyes', 'NNS'),
#  ('hair', 'NN'),
#  ('friends', 'NNS'),
#  ('called', 'VBN'),
#  ('auburn', 'VBP'),
#  ('sat', 'JJ'),
#  ('broad', 'JJ'),
#  ('red', 'JJ'),
#  ('sandstone', 'NN'),
#  ('doorstep', 'NN'),
#  ('edward', 'RB'),
#  ('farmhouse', 'NN'),
#  ('ripe', 'NN'),
#  ('firmly', 'RB'),
#  ('resolved', 'VBD'),
#  ('construe', 'JJ'),
#  ('many', 'JJ'),
#  ('virgil', 'NN'),
#  ('blue', 'JJ'),
#  ('hazes', 'VBZ'),
#  ('scarfing', 'VBG'),
#  ('harvest', 'JJS'),
#  ('slopes', 'NNS'),
#  ('little', 'JJ'),
#  ('winds', 'NNS'),
#  ('whispering', 'VBG'),
#  ('elfishly', 'RB'),
#  ('poplars', 'NNS'),
#  ('dancing', 'VBG'),
#  ('splendour', 'JJ'),
#  ('poppies', 'NNS'),
#  ('outflaming', 'VBG'),
#  ('dark', 'JJ'),
#  ('coppice', 'NN'),
#  ('young', 'JJ'),
#  ('firs', 'NNS'),
#  ('corner', 'NN'),
#  ('cherry', 'VBP'),
#  ('fitter', 'JJ'),
#  ('dreams', 'NNS'),
#  ('dead', 'JJ'),
#  ('languages', 'NNS'),
#  ('soon', 'RB'),
#  ('slipped', 'VBD'),
#  ('un', 'JJ'),
#  ('heeded', 'VBN'),
#  ('ground', 'NN'),
#  ('chin', 'NN'),
#  ('propped', 'VBD'),
#  ('clasped', 'JJ'),
#  ('hands', 'NNS'),
#  ('splendid', 'JJ'),
#  ('fluffy', 'NN'),
#  ('clouds', 'NNS'),
#  ('heaping', 'VBG'),
#  ('harrisons', 'NNS'),
#  ('like', 'IN'),
#  ('great', 'JJ'),
#  ('white', 'JJ'),
#  ('mountain', 'NN'),
#  ('far', 'RB'),
#  ('away', 'RB'),
#  ('delicious', 'JJ'),
#  ('world', 'NN'),
#  ('certain', 'JJ'),
#  ('schoolteacher', 'RB'),
#  ('wonderful', 'JJ'),
#  ('shap', 'NN'),
#  ('oe', 'IN'),
#  ('ing', 'VBG'),
#  ('destinies', 'NNS'),
#  ('future', 'JJ'),
#  ('statesmen', 'NNS'),
#  ('inspiring', 'VBG'),
#  ('youthful', 'JJ'),
#  ('minds', 'NNS'),
#  ('hearts', 'NNS'),
#  ('high', 'JJ'),
#  ('lofty', 'JJ'),
#  ('ambi', 'NN'),
#  ('tions', 'NNS'),
#  ('sure', 'JJ'),
#  ('came', 'VBD'),
#  ('harsh', 'JJ'),
#  ('facts', 'NNS'),
#  ('must', 'MD'),
#  ('confessed', 'VBN'),
#  ('seldom', 'NN'),
#  ('seem', 'VBP'),
#  ('likely', 'RB'),
#  ('much', 'JJ'),
#  ('promising', 'VBG'),
#  ('material', 'NN'),
#  ('celebrities', 'NNS'),
#  ('school', 'NN'),
#  ('could', 'MD'),
#  ('never', 'RB'),
#  ('tell', 'VB'),
#  ('might', 'MD'),
#  ('happen', 'VB'),
#  ('influence', 'NN'),
#  ('good', 'JJ'),
#  ('rose', 'VBD'),
#  ('tinted', 'JJ'),
#  ('ideals', 'NNS'),
#  ('accomplish', 'JJ'),
#  ('went', 'VBD'),
#  ('right', 'JJ'),
#  ('midst', 'NN'),
#  ('delightful', 'JJ'),
#  ('scene', 'NN'),
#  ('forty', 'NN'),
#  ('years', 'NNS'),
#  ('hence', 'RB'),
#  ('famous', 'JJ'),
#  ('personage', 'NN'),
#  ('exactly', 'RB'),
#  ('left', 'VBD'),
#  ('convenient', 'JJ'),
#  ('haziness', 'NN'),
#  ('thought', 'VBD'),
#  ('would', 'MD'),
#  ('rather', 'RB'),
#  ('nice', 'JJ'),
#  ('college', 'NN'),
#  ('president', 'NN'),
#  ('canadian', 'JJ'),
#  ('premier', 'NN'),
#  ('bowing', 'VBG'),
#  ('low', 'JJ'),
#  ('wrinkled', 'JJ'),
#  ('hand', 'NN'),
#  ('assuring', 'VBG'),
#  ('kindled', 'VBN'),
#  ('ambition', 'NN'),
#  ('success', 'NN'),
#  ('due', 'JJ'),
#  ('lessons', 'NNS'),
#  ('instilled', 'VBD'),
#  ('long', 'RB'),
#  ('ago', 'RB'),
#  ('pleasant', 'JJ'),
#  ('vision', 'NN'),
#  ('shattered', 'VBD'),
#  ('unpleasant', 'JJ'),
#  ('interrup', 'JJ'),
#  ('tion', 'NN'),
#  ('demure', 'NN'),
#  ('jersey', 'NN'),
#  ('cow', 'NN'),
#  ('scuttling', 'VBG'),
#  ('lane', 'JJ'),
#  ('five', 'CD'),
#  ('seconds', 'NNS'),
#  ('later', 'RB'),
#  ('arrived', 'VBD'),
#  ('mild', 'JJ'),
#  ('term', 'NN'),
#  ('describe', 'NN'),
#  ('manner', 'NN'),
#  ('irruption', 'NN'),
#  ('yard', 'NN'),
#  ('bounced', 'VBD'),
#  ('fence', 'NN'),
#  ('without', 'IN'),
#  ('waiting', 'VBG'),
#  ('open', 'JJ'),
#  ('gate', 'NN'),
#  ('angrily', 'RB'),
#  ('confronted', 'VBD'),
#  ('astonished', 'JJ'),
#  ('risen', 'NN'),
#  ('feet', 'NNS'),
#  ('stood', 'VBD'),
#  ('looking', 'VBG'),
#  ('bewilderment', 'NN'),
#  ('met', 'VBD'),
#  ('although', 'IN'),
#  ('seen', 'VBN'),
#  ('twice', 'RB'),
#  ('early', 'JJ'),
#  ('come', 'NN'),
#  ('robert', 'NN'),
#  ('bell', 'NN'),
#  ('queens', 'NNS'),
#  ('whose', 'WP$'),
#  ('farm', 'NN'),
#  ('adjoined', 'VBD'),
#  ('cuthbert', 'JJ'),
#  ('place', 'NN'),
#  ('west', 'JJS'),
#  ('sold', 'VBN'),
#  ('moved', 'VBD'),
#  ('charlottetown', 'JJ'),
#  ('bought', 'VBD'),
#  ('name', 'NN'),
#  ('fact', 'NN'),
#  ('brunswick', 'JJ'),
#  ('man', 'NN'),
#  ('known', 'VBN'),
#  ('month', 'NN'),
#  ('reputation', 'NN'),
#  ('odd', 'IN'),
#  ('person', 'NN'),
#  ('crank', 'NN'),
#  ('mrs', 'NN'),
#  ('rachel', 'NN'),
#  ('lynde', 'NN'),
#  ('said', 'VBD'),
#  ('outspoken', 'JJ'),
#  ('lady', 'NN'),
#  ('already', 'RB'),
#  ('acquaintance', 'JJ'),
#  ('member', 'NN'),
#  ('certainly', 'RB'),
#  ('different', 'JJ'),
#  ('people', 'NNS'),
#  ('essential', 'JJ'),
#  ('characteristic', 'JJ'),
#  ('everybody', 'NN'),
#  ('knows', 'VBZ'),
#  ('wanted', 'VBN'),
#  ('fools', 'NNS'),
#  ('women', 'NNS'),
#  ('kept', 'VBD'),
#  ('publicly', 'RB'),
#  ('stated', 'VBN'),
#  ('diggings', 'NNS'),
#  ('feminine', 'VBP'),
#  ('took', 'VBD'),
#  ('venge', 'NN'),
#  ('grewsome', 'NN'),
#  ('tales', 'NNS'),
#  ('related', 'VBN'),
#  ('hired', 'VBD'),
#  ('john', 'JJ'),
#  ('henry', 'NN'),
#  ('carter', 'NN'),
#  ('sands', 'NNS'),
#  ('started', 'VBD'),
#  ('keeping', 'VBG'),
#  ('cooking', 'VBG'),
#  ('stories', 'NNS'),
#  ('thing', 'NN'),
#  ('time', 'NN'),
#  ('meals', 'NNS'),
#  ('establishment', 'VBP'),
#  ('got', 'VBD'),
#  ('bite', 'JJ'),
#  ('felt', 'VBD'),
#  ('hungry', 'JJ'),
#  ('share', 'NN'),
#  ('wait', 'JJ'),
#  ('next', 'JJ'),
#  ('spell', 'NN'),
#  ('fully', 'RB'),
#  ('averred', 'VBD'),
#  ('wasnt', 'JJ'),
#  ('mourn', 'NN'),
#  ('starved', 'VBN'),
#  ('death', 'NN'),
#  ('sundays', 'NNS'),
#  ('filling', 'VBG'),
#  ('mother', 'NN'),
#  ('always', 'RB'),
#  ('gave', 'VBD'),
#  ('take', 'VB'),
#  ('basket', 'NN'),
#  ('grub', 'NN'),
#  ('monday', 'JJ'),
#  ('mornings', 'NNS'),
#  ('washing', 'VBG'),
#  ('dishes', 'NNS'),
#  ('pretence', 'NN'),
#  ('unless', 'IN'),
#  ('rainy', 'JJ'),
#  ('sunday', 'NN'),
#  ('washed', 'VBD'),
#  ('rainwater', 'NN'),
#  ('hogshead', 'NN'),
#  ('drain', 'NN'),
#  ('dry', 'JJ'),
#  ('asked', 'VBD'),
#  ('subscribe', 'JJ'),
#  ('rev', 'NN'),
#  ('close', 'JJ'),
#  ('allans', 'NNS'),
#  ('salary', 'JJ'),
#  ('hed', 'VBD'),
#  ('see', 'JJ'),
#  ('dollars', 'NNS'),
#  ('worth', 'JJ'),
#  ('preaching', 'VBG'),
#  ('didnt', 'NN'),
#  ('believe', 'VBP'),
#  ('buying', 'NN'),
#  ('pig', 'NN'),
#  ('poke', 'VBD'),
#  ('ask', 'JJ'),
#  ('contribution', 'NN'),
#  ('missions', 'NNS'),
#  ('incidentally', 'RB'),
#  ('inside', 'IN'),
#  ('told', 'VBN'),
#  ('heathens', 'NNS'),
#  ('old', 'JJ'),
#  ('among', 'IN'),
#  ('woman', 'NN'),
#  ('gossips', 'NNS'),
#  ('anywhere', 'RB'),
#  ('else', 'RB'),
#  ('knew', 'VBD'),
#  ('cheerfully', 'RB'),
#  ('contribute', 'JJ'),
#  ('mission', 'NN'),
#  ('christianizing', 'VBG'),
#  ('shed', 'VBD'),
#  ('undertake', 'JJ'),
#  ('mercy', 'NN'),
#  ('poor', 'JJ'),
#  ('safe', 'JJ'),
#  ('grave', 'NN'),
#  ('broken', 'VBN'),
#  ('heart', 'NN'),
#  ('state', 'NN'),
#  ('pride', 'NN'),
#  ('scrubbed', 'VBD'),
#  ('kitchen', 'JJ'),
#  ('floor', 'NN'),
#  ('every', 'DT'),
#  ('marilla', 'NN'),
#  ('indignantly', 'RB'),
#  ('skirts', 'VBZ'),
#  ('hold', 'NN'),
#  ('walked', 'VBD'),
#  ('across', 'IN'),
#  ('finally', 'RB'),
#  ('parrot', 'JJ'),
#  ('ginger', 'NN'),
#  ('nobody', 'NN'),
#  ('ever', 'RB'),
#  ('consequently', 'RB'),
#  ('proceeding', 'VBG'),
#  ('considered', 'VBN'),
#  ('respectable', 'JJ'),
#  ('barely', 'RB'),
#  ('bird', 'JJ'),
#  ('carters', 'NNS'),
#  ('word', 'NN'),
#  ('unholy', 'IN'),
#  ('swore', 'NN'),
#  ('terribly', 'RB'),
#  ('bitten', 'VBZ'),
#  ('taken', 'VBN'),
#  ('get', 'VB'),
#  ('another', 'DT'),
#  ('besides', 'IN'),
#  ('piece', 'NN'),
#  ('henrys', 'NN'),
#  ('neck', 'NN'),
#  ('stooped', 'VBD'),
#  ('near', 'IN'),
#  ('cage', 'NN'),
#  ('showed', 'VBD'),
#  ('mark', 'NN'),
#  ('luckless', 'NN'),
#  ('flashed', 'VBN'),
#  ('annes', 'NNS'),
#  ('mind', 'IN'),
#  ('quite', 'RB'),
#  ('speechless', 'JJ'),
#  ('wrath', 'NN'),
#  ('ap', 'NN'),
#  ('amiable', 'JJ'),
#  ('mood', 'NN'),
#  ('handsome', 'NN'),
#  ('parently', 'RB'),
#  ('short', 'JJ'),
#  ('fat', 'NN'),
#  ('bald', 'NN'),
#  ('round', 'NN'),
#  ('face', 'NN'),
#  ('purple', 'JJ'),
#  ('rage', 'NN'),
#  ('prominent', 'JJ'),
#  ('almost', 'RB'),
#  ('sticking', 'VBG'),
#  ('head', 'NN'),
#  ('really', 'RB'),
#  ('ugliest', 'JJ'),
#  ('im', 'NN'),
#  ('going', 'VBG'),
#  ('put', 'VBN'),
#  ('spluttered', 'JJ'),
#  ('bless', 'NN'),
#  ('soul', 'NN'),
#  ('longer', 'RBR'),
#  ('hear', 'JJ'),
#  ('shes', 'NNS'),
#  ('done', 'VBN'),
#  ('mean', 'JJ'),
#  ('let', 'NN'),
#  ('warned', 'VBD'),
#  ('occur', 'JJ'),
#  ('want', 'VBP'),
#  ('know', 'JJ'),
#  ('late', 'RB'),
#  ('considerably', 'RB'),
#  ('parent', 'NN'),
#  ('effect', 'NN'),
#  ('working', 'VBG'),
#  ('order', 'NN'),
#  ('began', 'VBD'),
#  ('practising', 'VBG'),
#  ('dignified', 'VBN'),
#  ('trouble', 'NN'),
#  ('explain', 'NN'),
#  ('virtue', 'NN'),
#  ('aunt', 'NN'),
#  ('last', 'JJ'),
#  ('pa', 'JJ'),
#  ('tience', 'NN'),
#  ('ceased', 'VBD'),
#  ('found', 'JJ'),
#  ('voice', 'NN'),
#  ('enough', 'JJ'),
#  ('think', 'NN'),
#  ('aunts', 'NNS'),
#  ('oats', 'VBP'),
#  ('minute', 'JJ'),
#  ('give', 'JJ'),
#  ('wheres', 'NNS'),
#  ('half', 'DT'),
#  ('hour', 'NN'),
#  ('tuesday', 'NN'),
#  ('yesterday', 'NN'),
#  ('distant', 'JJ'),
#  ('relative', 'JJ'),
#  ('gone', 'VBN'),
#  ('east', 'JJ'),
#  ('grafton', 'NN'),
#  ('ill', 'NN'),
#  ('increase', 'NN'),
#  ('dignity', 'NN'),
#  ('sorry', 'VBP'),
#  ('cuth', 'NN'),
#  ('matthew', 'VBP'),
#  ('three', 'CD'),
#  ('calf', 'NN'),
#  ('berts', 'NNS'),
#  ('isnt', 'VB'),
#  ('help', 'NN'),
#  ('matters', 'NNS'),
#  ('youd', 'VBP'),
#  ('better', 'JJR'),
#  ('go', 'VB'),
#  ('look', 'RBR'),
#  ('havoc', 'JJ'),
#  ('ani', 'NN'),
#  ('mal', 'NN'),
#  ('trampled', 'VBD'),
#  ('centre', 'JJ'),
#  ('circumference', 'NN'),
#  ('repeated', 'VBD'),
#  ('oatfield', 'JJ'),
#  ('pasture', 'NN'),
#  ('noticed', 'VBN'),
#  ('separates', 'NNS'),
#  ('fences', 'NNS'),
#  ('repair', 'VBP'),
#  ('dolly', 'RB'),
#  ('perhaps', 'RB'),
#  ('6', 'CD'),
#  ('condition', 'NN'),
#  ('snapped', 'VBD'),
#  ('angrier', 'JJR'),
#  ('carrying', 'VBG'),
#  ('war', 'NN'),
#  ('enemys', 'NN'),
#  ('demon', 'NN'),
#  ('jail', 'NN'),
#  ('couldnt', 'NN'),
#  ('keep', 'VB'),
#  ('redheaded', 'JJ'),
#  ('snippet', 'NNS'),
#  ('say', 'VBP'),
#  ('employed', 'VBN'),
#  ('watching', 'VBG'),
#  ('peoples', 'NNS'),
#  ('grain', 'VBP'),
#  ('sitting', 'VBG'),
#  ('read', 'NN'),
#  ('scathing', 'VBG'),
#  ('glance', 'NN'),
#  ('innocent', 'NN'),
#  ('tancoloured', 'VBD'),
#  ('yellowcovered', 'JJ'),
#  ('something', 'NN'),
#  ('moment', 'NN'),
#  ('tender', 'NN'),
#  ('point', 'NN'),
#  ('id', 'VBP'),
#  ('none', 'NN'),
#  ('except', 'IN'),
#  ('fringe', 'NN'),
#  ('ears', 'NNS'),
#  ('shot', 'JJ'),
#  ('sensitive', 'JJ'),
#  ('anger', 'NN'),
#  ('choked', 'VBD'),
#  ('glare', 'NN'),
#  ('speechlessly', 'RB'),
#  ('recovered', 'VBD'),
#  ('temper', 'NN'),
#  ('followed', 'VBD'),
#  ('advan', 'JJ'),
#  ('tage', 'NN'),
#  ('cause', 'NN'),
#  ('make', 'VBP'),
#  ('allowance', 'NN'),
#  ('imagination', 'NN'),
#  ('easily', 'RB'),
#  ('imagine', 'VB'),
#  ('trying', 'VBG'),
#  ('find', 'VB'),
#  ('shall', 'MD'),
#  ('cherish', 'VB'),
#  ('feelings', 'NNS'),
#  ('youve', 'RB'),
#  ('promise', 'VBP'),
#  ('break', 'VB'),
#  ('honour', 'PRP$'),
#  ('well', 'RB'),
#  ('doesnt', 'RB'),
#  ('muttered', 'VBN'),
#  ('rison', 'NN'),
#  ('somewhat', 'RB'),
#  ('subdued', 'VBD'),
#  ('tone', 'JJ'),
#  ('har', 'NN'),
#  ('stamped', 'VBD'),
#  ('heard', 'RB'),
#  ('growling', 'VBG'),
#  ('earshot', 'JJ'),
#  ('grievously', 'RB'),
#  ('disturbed', 'VBN'),
#  ('marched', 'VBN'),
#  ('shut', 'NN'),
#  ('naughty', 'NN'),
#  ('milking', 'VBG'),
#  ('pen', 'JJ'),
#  ('cant', 'NN'),
#  ('possibly', 'RB'),
#  ('tears', 'NNS'),
#  ('reflected', 'VBD'),
#  ('quiet', 'JJ'),
#  ('daresay', 'JJ'),
#  ('looks', 'NNS'),
#  ('pretty', 'RB'),
#  ('sickened', 'VBD'),
#  ('wish', 'JJ'),
#  ('shearer', 'NN'),
#  ('week', 'NN'),
#  ('auction', 'NN'),
#  ('stock', 'NN'),
#  ('together', 'RB'),
#  ('true', 'JJ'),
#  ('theres', 'NNS'),
#  ('noth', 'DT'),
#  ('kindred', 'VBN'),
#  ('spirit', 'NN'),
#  ('weather', 'NN'),
#  ('eye', 'NN'),
#  ('spirits', 'NNS'),
#  ('driving', 'VBG'),
#  ('latter', 'NN'),
#  ('flew', 'VBD'),
#  ('returned', 'VBN'),
#  ('discussed', 'JJ'),
#  ('matter', 'NN'),
#  ('tea', 'NN'),
#  ('table', 'JJ'),
#  ('glad', 'JJ'),
#  ('ready', 'JJ'),
#  ('rilla', 'NN'),
#  ('responsibility', 'NN'),
#  ('unreliable', 'JJ'),
#  ('martin', 'NN'),
#  ('yet', 'RB'),
#  ('promised', 'VBN'),
#  ('night', 'NN'),
#  ('funeral', 'JJ'),
#  ('dont', 'NN'),
#  ('thats', 'NNS'),
#  ('died', 'VBD'),
#  ('since', 'IN'),
#  ('year', 'NN'),
#  ('thankful', 'JJ'),
#  ('crop', 'NN'),
#  ('barry', 'NN'),
#  ('takes', 'VBZ'),
#  ('tin', 'NN'),
#  ('till', 'NN'),
#  ('mar', 'NN'),
#  ('fixed', 'VBN'),
#  ('says', 'VBZ'),
#  ('declare', 'NN'),
#  ('heres', 'NNS'),
#  ('mary', 'VBP'),
#  ('keith', 'NN'),
#  ('dying', 'VBG'),
#  ('become', 'VBN'),
#  ('two', 'CD'),
#  ('chil', 'JJ'),
#  ('dren', 'NNS'),
#  ('british', 'JJ'),
#  ('columbia', 'VBP'),
#  ('brother', 'RB'),
#  ('written', 'VBN'),
#  ('hasnt', 'JJ'),
#  ('children', 'NNS'),
#  ('six', 'CD'),
#  ('past', 'JJ'),
#  ('theyre', 'NN'),
#  ('twins', 'NNS'),
#  ('oh', 'VBP'),
#  ('ive', 'JJ'),
#  ('especially', 'RB'),
#  ('interested', 'JJ'),
#  ('hammond', 'NN'),
#  ('eagerly', 'RB'),
#  ('goodness', 'JJ'),
#  ('dirty', 'NN'),
#  ('making', 'VBG'),
#  ('mud', 'JJ'),
#  ('pies', 'NNS'),
#  ('call', 'VBP'),
#  ...]

# %%
import re
parts = [len(l.split()) for l in re.split(r'[?!.]', text) if l.strip()]

print(sum(parts)/len(parts))
# Out:
# 13.414864115363283
