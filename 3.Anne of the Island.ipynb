# %%
import os
DATA_DIR = 'txtfile'
fname = 'Anne of the Island mdp.39015013118545-1560362417.txt'
fname = os.path.join(DATA_DIR, fname)
with open(fname, encoding='utf-8') as f:
    text = f.read()
from string import punctuation
no_punct = ''.join([ch for ch in text if ch not in punctuation])
lower_text=no_punct.lower()

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(lower_text) 
  
clean_text = [w for w in word_tokens if not w in stop_words] 
  
clean_text = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        clean_text.append(w) 

stop=['“', '”','’','—']
filtered_word = [w for w in clean_text if not w in stop]

filtered_word = []

for w in clean_text: 
    if w not in stop: 
        filtered_word.append(w) 
        
print(filtered_word)
# Out:
# ['chapter', 'r', 'shadow', 'change', 'harvest', 'ended', 'summer', 'gone', 'quoted', 'anne', 'shirley', 'gazing', 'across', 'shorn', 'fields', 'dream', 'ily', 'diana', 'barry', 'picking', 'apples', 'green', 'gables', 'orchard', 'resting', 'labours', 'sunny', 'corner', 'airy', 'fleets', 'thistledown', 'drifted', 'wings', 'wind', 'still', 'summersweet', 'incense', 'ferns', 'haunted', 'wood', 'everything', 'landscape', 'around', 'spoke', 'autumn', 'sea', 'roaring', 'hollowly', 'dis', 'tance', 'fields', 'bare', 'sere', 'scarfed', 'golden', 'rod', 'brook', 'valley', 'green', 'gables', 'overflowed', 'asters', 'ethereal', 'purple', 'lake', 'shining', 'waters', 'blue', 'blue', 'blue', 'blue', 'changeful', 'spring', 'pale', 'azure', 'summer', 'clear', 'steadfast', 'serene', 'blue', 'water', 'past', 'moods', 'tenses', 'emotion', 'settled', 'tranquillity', 'unbroken', 'fickle', 'dreams', 'nice', 'summer', 'said', 'diana', 'twisting', 'anne', 'island', '9', 'new', 'ring', 'left', 'hand', 'smile', 'miss', 'lavendars', 'wedding', 'seemed', 'come', 'sort', 'suppose', 'crown', 'mr', 'mrs', 'irving', 'pacific', 'coast', 'seems', 'gone', 'long', 'enough', 'go', 'around', 'world', 'sighed', 'anne', 'cant', 'believe', 'week', 'since', 'married', 'everything', 'changed', 'miss', 'lavendar', 'mr', 'mrs', 'allan', 'gone', 'lonely', 'manse', 'looks', 'shutters', 'closed', 'went', 'past', 'last', 'night', 'made', 'feel', 'well', 'everybody', 'died', 'never', 'get', 'another', 'minister', 'nice', 'mr', 'allan', 'said', 'diana', 'gloomy', 'conviction', 'sup', 'pose', 'well', 'kinds', 'supplies', 'winter', 'half', 'sundays', 'preaching', 'gilbert', 'gone', 'awfully', 'dull', 'fred', 'insinuated', 'anne', 'slyly', 'mrs', 'lynde', 'going', 'move', 'diana', 'asked', 'heard', 'annes', 'remark', 'tomorrow', 'im', 'glad', 'shes', 'coming', 'another', 'change', 'marilla', 'cleared', 'everything', 'know', 'spare', 'room', 'yesterday', 'hated', 'course', 'silly', 'seem', 'committing', 'sacrilege', 'old', 'spare', 'room', 'always', 'seemed', 'like', 'shrine', 'child', 'thought', 'wonderful', 'apartment', 'world', 'suming', 'desire', 'remember', 'sleep', 'spare', 'room', 'bed', 'green', 'gables', 'spare', 'room', 'would', 'terrible', 'con', 'oh', 'never', '—i', 'couldnt', 'slept', 'shadow', 'wink', 'awe', 'change', '3', 'never', 'walked', 'room', 'marilla', 'sent', 'errand', 'tiptoed', 'held', 'breath', 'church', 'felt', 'relieved', 'indeed', 'got', 'pictures', 'george', 'whitefield', 'duke', 'welling', 'ton', 'hung', 'one', 'side', 'mirror', 'frowned', 'sternly', 'time', 'espe', 'cially', 'dared', 'peep', 'mirror', 'one', 'house', 'didnt', 'twist', 'face', 'little', 'always', 'wondered', 'marilla', 'dared', 'houseclean', 'room', 'bare', 'cleaned', 'stripped', 'george', 'whitefield', 'duke', 'rele', 'passes', 'glory', 'world', 'concluded', 'anne', 'laugh', 'little', 'note', 'regret', 'never', 'pleasant', 'gated', 'upstairs', 'hall', 'old', 'shrines', 'desecrated', 'even', 'outgrown', 'ill', 'lonesome', 'go', 'moaned', 'diana', 'hundredth', 'time', 'think', 'go', 'next', 'week', 'together', 'still', 'said', 'anne', 'cheerily', 'mustnt', 'let', 'next', 'week', 'rob', 'us', 'weeks', 'joy', 'hate', 'thought', 'going', 'home', 'talk', 'lonesome', 'groan', 'youll', 'number', 'old', 'friends', 'fred', 'shall', 'alone', 'among', 'strangers', 'knowing', 'soul', 'good', 'friends', 'except', 'gilbert', 'charlie', 'sloane', 'said', 'diana', 'imitating', 'annes', 'italics', 'slyness', 'charlie', 'sloane', 'great', 'comfort', 'course', 'anne', 'island', '4', 'agreed', 'anne', 'sarcastically', 'whereupon', 'irre', 'diana', 'knew', 'exactly', 'anne', 'thought', 'charlie', 'sloane', 'despite', 'sundry', 'sponsible', 'damsels', 'laughed', 'confidential', 'talks', 'know', 'anne', 'thought', 'gilbert', 'blythe', 'sure', 'anne', 'know', 'boys', 'may', 'boarding', 'end', 'kingsport', 'glad', 'im', 'going', 'redmond', 'wont', 'sure', 'first', 'weeks', 'know', 'anne', 'went', 'shall', 'li ...

# %%
from collections import Counter
freq = Counter(filtered_text)
freq.most_common
# Out:
# <bound method Counter.most_common of Counter({'anne': 1126, 'said': 577, 'one': 323, 'would': 266, 'like': 243, 'never': 233, 'dont': 227, 'im': 224, 'mrs': 222, 'old': 211, 'little': 189, 'know': 181, 'well': 180, 'think': 172, 'could': 172, 'phil': 171, 'davy': 160, 'oh': 160, 'gilbert': 156, 'go': 153, 'island': 151, 'going': 148, 'time': 146, 'see': 141, 'come': 138, 'home': 133, 'ever': 128, 'thought': 126, 'diana': 125, 'place': 119, 'good': 119, 'say': 118, 'came': 117, 'always': 116, 'ive': 112, 'must': 112, 'miss': 111, 'aunt': 110, 'much': 109, 'life': 108, 'want': 108, 'cant': 104, 'get': 104, 'day': 103, 'ill': 102, 'years': 100, 'last': 99, 'things': 99, 'love': 96, 'marilla': 92, 'went': 91, 'asked': 91, 'away': 91, 'back': 91, 'wont': 89, 'eyes': 89, 'lynde': 86, 'got': 86, 'take': 86, 'made': 85, 'really': 85, 'priscilla': 85, 'night': 84, 'feel': 83, 'redmond': 82, 'even': 82, 'isnt': 82, 'two': 81, 'first': 79, 'girls': 78, 'long': 78, 'janet': 76, 'mr': 75, 'couldnt': 75, 'way': 74, 'didnt': 74, 'id': 74, 'man': 74, 'told': 74, 'look': 72, 'dear': 71, 'mother': 71, 'us': 70, 'something': 70, 'jamesina': 70, 'green': 69, 'knew': 69, 'make': 69, 'evening': 68, 'felt': 68, 'tell': 68, 'ruby': 68, 'poor': 67, 'marry': 65, 'rather': 64, 'story': 64, 'pattys': 63, 'nice': 63, 'suppose': 63, 'great': 63, 'yes': 63, 'course': 62, 'next': 61, 'white': 61, 'house': 60, 'gone': 60, 'annes': 59, 'youll': 59, 'sure': 59, 'quite': 59, 'right': 59, 'anything': 58, 'left': 58, 'jane': 58, 'looked': 58, 'avonlea': 57, 'heart': 57, 'coming': 56, 'put': 56, 'ing': 56, 'still': 55, 'room': 55, 'face': 55, 'let': 54, 'thats': 54, 'school': 54, 'roy': 54, 'thing': 53, 'big': 53, 'wouldnt': 53, 'people': 52, 'douglas': 52, 'shall': 52, 'mind': 52, 'better': 52, 'every': 52, 'yet': 52, 'world': 51, 'might': 51, 'theres': 51, 'stella': 51, 'wanted': 50, 'believe': 50, 'many': 50, 'says': 50, 'saw': 50, 'seemed': 49, 'shes': 49, 'laughed': 48, 'dora': 48, 'live': 48, 'enough': 47, 'since': 47, 'married': 47, 'found': 47, 'nothing': 47, 'took': 46, 'week': 45, 'glad': 45, 'looking': 45, 'hope': 45, 'chapter': 43, 'year': 43, 'girl': 43, 'head': 43, 'else': 43, 'without': 43, 'gables': 42, 'young': 42, 'three': 42, 'sat': 42, 'done': 42, 'john': 41, 'talk': 41, 'though': 41, 'new': 40, 'bed': 40, 'real': 40, 'call': 39, 'give': 39, 'keep': 39, 'hear': 39, 'bad': 39, 'find': 38, 'everything': 38, 'charlie': 38, 'sloane': 38, 'wasnt': 38, 'ask': 38, 'gave': 38, 'pretty': 38, 'behind': 38, 'turned': 37, 'shirley': 37, 'alone': 37, 'havent': 37, 'morning': 37, 'summer': 36, 'around': 36, 'afraid': 36, 'word': 36, 'hair': 36, 'beautiful': 36, 'hes': 36, 'road': 36, 'soon': 36, 'rusty': 36, 'youre': 35, 'gray': 35, 'woman': 35, 'may': 34, 'soul': 34, 'read': 34, 'along': 34, 'cats': 34, 'black': 34, 'half': 33, 'heard': 33, 'laugh': 33, 'college': 33, 'awful': 33, 'name': 33, 'letter': 32, 'jonas': 32, 'blue': 32, 'seem': 32, 'sweet': 32, 'far': 32, 'youd': 32, 'nobody': 32, 'loved': 32, 'care': 32, 'work': 31, 'used': 31, 'dreams': 31, 'philippa': 31, 'another': 31, 'church': 31, 'days': 31, 'full': 31, 'andrews': 31, 'rachel': 31, 'doesnt': 31, 'certainly': 31, 'park': 30, 'almost': 30, 'write': 30, 'lady': 29, 'hand': 29, 'father': 29, 'boy': 29, 'red': 29, 'bit': 29, 'happy': 29, 'mean': 29, 'youve': 29, 'letters': 28, 'round': 28, 'friends': 28, 'kingsport': 28, 'matter': 28, 'till': 28, 'seen': 28, 'best': 28, 'tired': 28, 'given': 28, 'cat': 28, 'spring': 27, 'winter': 27, 'speak': 27, 'sitting': 27, 'called': 27, 'dress': 27, 'gillis': 27, 'hard': 27, 'ago': 27, 'seems': 26, 'help': 26, 'billy': 26, 'times': 26, 'sunday': 26, 'porch': 26, 'de': 26, 'door': 26, 'today': 26, 'joseph': 26, 'pale': 25, 'past': 25, 'died': 25, 'aint': 25, 'theyre': 25, 'box': 25, 'getting': 25, 'kind': 25, 'least': 25, 'hadnt': 25, 'harrison': 25, 'walked': 24, 'together': 24, 'blythe': 24, 'suddenly': 24, 'walk': 24, 'light': 24, 'sorry': 24, 'wish': 24, ...

# %%
from collections import Counter
freq = Counter(filtered_text)
freq.most_common
# Out:
# <bound method Counter.most_common of Counter({'anne': 1126, 'said': 577, 'one': 323, 'would': 266, 'like': 243, 'never': 233, 'dont': 227, 'im': 224, 'mrs': 222, 'old': 211, 'little': 189, 'know': 181, 'well': 180, 'think': 172, 'could': 172, 'phil': 171, 'davy': 160, 'oh': 160, 'gilbert': 156, 'go': 153, 'island': 151, 'going': 148, 'time': 146, 'see': 141, 'come': 138, 'home': 133, 'ever': 128, 'thought': 126, 'diana': 125, 'place': 119, 'good': 119, 'say': 118, 'came': 117, 'always': 116, 'ive': 112, 'must': 112, 'miss': 111, 'aunt': 110, 'much': 109, 'life': 108, 'want': 108, 'cant': 104, 'get': 104, 'day': 103, 'ill': 102, 'years': 100, 'last': 99, 'things': 99, 'love': 96, 'marilla': 92, 'went': 91, 'asked': 91, 'away': 91, 'back': 91, 'wont': 89, 'eyes': 89, 'lynde': 86, 'got': 86, 'take': 86, 'made': 85, 'really': 85, 'priscilla': 85, 'night': 84, 'feel': 83, 'redmond': 82, 'even': 82, 'isnt': 82, 'two': 81, 'first': 79, 'girls': 78, 'long': 78, 'janet': 76, 'mr': 75, 'couldnt': 75, 'way': 74, 'didnt': 74, 'id': 74, 'man': 74, 'told': 74, 'look': 72, 'dear': 71, 'mother': 71, 'us': 70, 'something': 70, 'jamesina': 70, 'green': 69, 'knew': 69, 'make': 69, 'evening': 68, 'felt': 68, 'tell': 68, 'ruby': 68, 'poor': 67, 'marry': 65, 'rather': 64, 'story': 64, 'pattys': 63, 'nice': 63, 'suppose': 63, 'great': 63, 'yes': 63, 'course': 62, 'next': 61, 'white': 61, 'house': 60, 'gone': 60, 'annes': 59, 'youll': 59, 'sure': 59, 'quite': 59, 'right': 59, 'anything': 58, 'left': 58, 'jane': 58, 'looked': 58, 'avonlea': 57, 'heart': 57, 'coming': 56, 'put': 56, 'ing': 56, 'still': 55, 'room': 55, 'face': 55, 'let': 54, 'thats': 54, 'school': 54, 'roy': 54, 'thing': 53, 'big': 53, 'wouldnt': 53, 'people': 52, 'douglas': 52, 'shall': 52, 'mind': 52, 'better': 52, 'every': 52, 'yet': 52, 'world': 51, 'might': 51, 'theres': 51, 'stella': 51, 'wanted': 50, 'believe': 50, 'many': 50, 'says': 50, 'saw': 50, 'seemed': 49, 'shes': 49, 'laughed': 48, 'dora': 48, 'live': 48, 'enough': 47, 'since': 47, 'married': 47, 'found': 47, 'nothing': 47, 'took': 46, 'week': 45, 'glad': 45, 'looking': 45, 'hope': 45, 'chapter': 43, 'year': 43, 'girl': 43, 'head': 43, 'else': 43, 'without': 43, 'gables': 42, 'young': 42, 'three': 42, 'sat': 42, 'done': 42, 'john': 41, 'talk': 41, 'though': 41, 'new': 40, 'bed': 40, 'real': 40, 'call': 39, 'give': 39, 'keep': 39, 'hear': 39, 'bad': 39, 'find': 38, 'everything': 38, 'charlie': 38, 'sloane': 38, 'wasnt': 38, 'ask': 38, 'gave': 38, 'pretty': 38, 'behind': 38, 'turned': 37, 'shirley': 37, 'alone': 37, 'havent': 37, 'morning': 37, 'summer': 36, 'around': 36, 'afraid': 36, 'word': 36, 'hair': 36, 'beautiful': 36, 'hes': 36, 'road': 36, 'soon': 36, 'rusty': 36, 'youre': 35, 'gray': 35, 'woman': 35, 'may': 34, 'soul': 34, 'read': 34, 'along': 34, 'cats': 34, 'black': 34, 'half': 33, 'heard': 33, 'laugh': 33, 'college': 33, 'awful': 33, 'name': 33, 'letter': 32, 'jonas': 32, 'blue': 32, 'seem': 32, 'sweet': 32, 'far': 32, 'youd': 32, 'nobody': 32, 'loved': 32, 'care': 32, 'work': 31, 'used': 31, 'dreams': 31, 'philippa': 31, 'another': 31, 'church': 31, 'days': 31, 'full': 31, 'andrews': 31, 'rachel': 31, 'doesnt': 31, 'certainly': 31, 'park': 30, 'almost': 30, 'write': 30, 'lady': 29, 'hand': 29, 'father': 29, 'boy': 29, 'red': 29, 'bit': 29, 'happy': 29, 'mean': 29, 'youve': 29, 'letters': 28, 'round': 28, 'friends': 28, 'kingsport': 28, 'matter': 28, 'till': 28, 'seen': 28, 'best': 28, 'tired': 28, 'given': 28, 'cat': 28, 'spring': 27, 'winter': 27, 'speak': 27, 'sitting': 27, 'called': 27, 'dress': 27, 'gillis': 27, 'hard': 27, 'ago': 27, 'seems': 26, 'help': 26, 'billy': 26, 'times': 26, 'sunday': 26, 'porch': 26, 'de': 26, 'door': 26, 'today': 26, 'joseph': 26, 'pale': 25, 'past': 25, 'died': 25, 'aint': 25, 'theyre': 25, 'box': 25, 'getting': 25, 'kind': 25, 'least': 25, 'hadnt': 25, 'harrison': 25, 'walked': 24, 'together': 24, 'blythe': 24, 'suddenly': 24, 'walk': 24, 'light': 24, 'sorry': 24, 'wish': 24, ...

# %%
from nltk.probability import FreqDist
Fdist = FreqDist(filtered_text)
print(Fdist)
# Out:
# <FreqDist with 8216 samples and 42044 outcomes>

# %%
Fdist['anne']
# Out:
# 1126

# %%
Fdist['anne']/len(word_tokens)
# Out:
# 0.014109568442684578

# %%
Fdist.plot(50, cumulative=True)

# %%
filtered_text=' '.join(filtered_word)

# %%
import os
os.path
# !pip install wordcloud
import wordcloud
from wordcloud import WordCloud
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
wordcloud = WordCloud(max_words=150,background_color="white").generate(lower_text)
plt.figure(figsize=(16,12))
# plot wordcloud in matplotlib
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Requirement already satisfied: wordcloud in /Applications/anaconda3/lib/python3.7/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /Applications/anaconda3/lib/python3.7/site-packages (from wordcloud) (1.16.2)
# Requirement already satisfied: pillow in /Applications/anaconda3/lib/python3.7/site-packages (from wordcloud) (5.4.1)

# %%
wordcloud.to_file("txtfile/Anne of the Island.png")

# %%
import nltk
freqdist = nltk.FreqDist(filtered_word)
plt.figure(figsize=(16,5))
freqdist.plot(50)

# %%
lexical_diversity = len(set(word_tokens)) / len(word_tokens)
lexical_diversity
# Out:
# 0.10357876798155481

# %%
len(set(word_tokens))
# Out:
# 8266

# %%
len(word_tokens)
# Out:
# 79804

# %%
[len(w) for w in word_tokens]
# Out:
# [7,
#  1,
#  1,
#  3,
#  6,
#  2,
#  6,
#  7,
#  2,
#  5,
#  3,
#  6,
#  2,
#  4,
#  6,
#  4,
#  7,
#  6,
#  6,
#  3,
#  5,
#  6,
#  5,
#  3,
#  3,
#  3,
#  5,
#  5,
#  3,
#  4,
#  7,
#  6,
#  2,
#  3,
#  5,
#  6,
#  7,
#  3,
#  4,
#  3,
#  7,
#  4,
#  5,
#  7,
#  2,
#  1,
#  5,
#  6,
#  5,
#  4,
#  6,
#  2,
#  11,
#  7,
#  2,
#  2,
#  3,
#  5,
#  2,
#  1,
#  4,
#  4,
#  3,
#  5,
#  11,
#  4,
#  3,
#  7,
#  2,
#  5,
#  2,
#  3,
#  7,
#  4,
#  3,
#  10,
#  2,
#  3,
#  9,
#  6,
#  4,
#  5,
#  2,
#  6,
#  3,
#  3,
#  3,
#  7,
#  8,
#  2,
#  3,
#  3,
#  5,
#  3,
#  6,
#  4,
#  4,
#  3,
#  4,
#  7,
#  4,
#  6,
#  3,
#  3,
#  5,
#  6,
#  5,
#  5,
#  6,
#  10,
#  4,
#  6,
#  2,
#  8,
#  6,
#  3,
#  3,
#  4,
#  2,
#  7,
#  6,
#  3,
#  4,
#  1,
#  4,
#  4,
#  2,
#  1,
#  4,
#  3,
#  3,
#  9,
#  6,
#  3,
#  3,
#  4,
#  5,
#  2,
#  6,
#  3,
#  1,
#  5,
#  9,
#  6,
#  4,
#  2,
#  2,
#  3,
#  5,
#  4,
#  4,
#  3,
#  5,
#  3,
#  6,
#  2,
#  7,
#  3,
#  3,
#  7,
#  4,
#  2,
#  1,
#  12,
#  8,
#  2,
#  6,
#  6,
#  2,
#  3,
#  4,
#  1,
#  4,
#  6,
#  4,
#  5,
#  8,
#  4,
#  2,
#  3,
#  6,
#  1,
#  3,
#  3,
#  3,
#  4,
#  2,
#  3,
#  4,
#  4,
#  4,
#  1,
#  5,
#  4,
#  9,
#  7,
#  6,
#  2,
#  4,
#  2,
#  1,
#  4,
#  2,
#  1,
#  7,
#  5,
#  2,
#  2,
#  2,
#  3,
#  3,
#  6,
#  3,
#  2,
#  3,
#  7,
#  5,
#  3,
#  2,
#  5,
#  2,
#  2,
#  4,
#  4,
#  4,
#  4,
#  4,
#  6,
#  2,
#  2,
#  6,
#  3,
#  5,
#  6,
#  4,
#  1,
#  4,
#  7,
#  2,
#  2,
#  4,
#  1,
#  4,
#  5,
#  4,
#  4,
#  7,
#  10,
#  3,
#  7,
#  4,
#  8,
#  3,
#  2,
#  3,
#  3,
#  5,
#  4,
#  1,
#  3,
#  6,
#  3,
#  5,
#  5,
#  4,
#  3,
#  8,
#  3,
#  6,
#  1,
#  4,
#  4,
#  2,
#  4,
#  5,
#  3,
#  2,
#  4,
#  2,
#  4,
#  2,
#  4,
#  2,
#  9,
#  2,
#  2,
#  3,
#  4,
#  5,
#  3,
#  7,
#  8,
#  2,
#  4,
#  2,
#  2,
#  5,
#  4,
#  5,
#  4,
#  6,
#  10,
#  1,
#  3,
#  4,
#  4,
#  4,
#  3,
#  5,
#  2,
#  8,
#  4,
#  6,
#  3,
#  4,
#  3,
#  7,
#  2,
#  9,
#  2,
#  3,
#  3,
#  3,
#  3,
#  7,
#  4,
#  1,
#  2,
#  4,
#  2,
#  7,
#  4,
#  4,
#  4,
#  2,
#  4,
#  10,
#  4,
#  5,
#  4,
#  2,
#  3,
#  5,
#  5,
#  2,
#  4,
#  2,
#  5,
#  2,
#  2,
#  5,
#  3,
#  3,
#  3,
#  5,
#  5,
#  6,
#  8,
#  2,
#  4,
#  4,
#  6,
#  1,
#  3,
#  2,
#  4,
#  2,
#  7,
#  6,
#  7,
#  3,
#  1,
#  7,
#  10,
#  2,
#  3,
#  4,
#  1,
#  3,
#  2,
#  3,
#  5,
#  4,
#  9,
#  5,
#  2,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  5,
#  1,
#  3,
#  2,
#  3,
#  4,
#  2,
#  2,
#  2,
#  4,
#  10,
#  9,
#  4,
#  3,
#  5,
#  4,
#  3,
#  6,
#  6,
#  4,
#  1,
#  6,
#  2,
#  2,
#  4,
#  1,
#  3,
#  1,
#  5,
#  1,
#  7,
#  2,
#  3,
#  4,
#  9,
#  9,
#  2,
#  3,
#  5,
#  6,
#  6,
#  1,
#  3,
#  8,
#  4,
#  3,
#  2,
#  5,
#  2,
#  1,
#  5,
#  4,
#  3,
#  3,
#  3,
#  5,
#  6,
#  5,
#  4,
#  2,
#  5,
#  4,
#  4,
#  3,
#  8,
#  1,
#  3,
#  1,
#  3,
#  2,
#  2,
#  5,
#  5,
#  2,
#  7,
#  4,
#  5,
#  3,
#  6,
#  1,
#  4,
#  4,
#  3,
#  1,
#  2,
#  6,
#  1,
#  5,
#  6,
#  7,
#  4,
#  4,
#  4,
#  7,
#  4,
#  2,
#  2,
#  2,
#  2,
#  6,
#  1,
#  2,
#  7,
#  7,
#  2,
#  3,
#  4,
#  2,
#  6,
#  2,
#  6,
#  3,
#  4,
#  8,
#  4,
#  1,
#  2,
#  6,
#  1,
#  1,
#  4,
#  2,
#  3,
#  3,
#  2,
#  2,
#  3,
#  8,
#  2,
#  6,
#  10,
#  3,
#  3,
#  4,
#  2,
#  7,
#  3,
#  4,
#  5,
#  3,
#  2,
#  4,
#  4,
#  2,
#  3,
#  6,
#  3,
#  7,
#  2,
#  7,
#  2,
#  2,
#  3,
#  3,
#  4,
#  1,
#  3,
#  2,
#  4,
#  6,
#  2,
#  1,
#  5,
#  4,
#  2,
#  3,
#  6,
#  5,
#  3,
#  3,
#  4,
#  3,
#  2,
#  3,
#  5,
#  4,
#  5,
#  5,
#  2,
#  4,
#  1,
#  6,
#  1,
#  6,
#  8,
#  3,
#  7,
#  5,
#  10,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  4,
#  7,
#  3,
#  8,
#  6,
#  10,
#  3,
#  3,
#  4,
#  4,
#  4,
#  4,
#  2,
#  6,
#  3,
#  5,
#  2,
#  4,
#  5,
#  9,
#  4,
#  4,
#  1,
#  5,
#  2,
#  5,
#  5,
#  3,
#  1,
#  6,
#  4,
#  2,
#  6,
#  2,
#  2,
#  5,
#  8,
#  5,
#  2,
#  3,
#  8,
#  4,
#  2,
#  4,
#  3,
#  3,
#  7,
#  10,
#  4,
#  4,
#  2,
#  4,
#  8,
#  4,
#  3,
#  2,
#  2,
#  8,
#  4,
#  3,
#  2,
#  6,
#  5,
#  3,
#  3,
#  9,
#  4,
#  3,
#  2,
#  5,
#  3,
#  2,
#  4,
#  4,
#  3,
#  4,
#  8,
#  5,
#  4,
#  4,
#  8,
#  2,
#  6,
#  3,
#  4,
#  4,
#  3,
#  2,
#  2,
#  4,
#  5,
#  3,
#  1,
#  4,
#  3,
#  7,
#  2,
#  5,
#  6,
#  1,
#  4,
#  3,
#  1,
#  3,
#  4,
#  2,
#  5,
#  8,
#  3,
#  1,
#  3,
#  6,
#  5,
#  5,
#  2,
#  4,
#  4,
#  3,
#  6,
#  2,
#  4,
#  3,
#  7,
#  1,
#  3,
#  4,
#  5,
#  1,
#  5,
#  2,
#  5,
#  5,
#  9,
#  3,
#  7,
#  1,
#  4,
#  4,
#  4,
#  7,
#  6,
#  7,
#  1,
#  3,
#  7,
#  6,
#  4,
#  5,
#  9,
#  5,
#  7,
#  3,
#  7,
#  7,
#  6,
#  4,
#  2,
#  1,
#  5,
#  7,
#  2,
#  6,
#  4,
#  2,
#  3,
#  6,
#  1,
#  6,
#  4,
#  13,
#  9,
#  4,
#  5,
#  4,
#  5,
#  4,
#  7,
#  4,
#  4,
#  7,
#  2,
#  7,
#  6,
#  3,
#  7,
#  6,
#  9,
#  7,
#  7,
#  12,
#  5,
#  3,
#  3,
#  3,
#  4,
#  4,
#  4,
#  4,
#  2,
#  7,
#  2,
#  7,
#  6,
#  2,
#  4,
#  4,
#  7,
#  3,
#  3,
#  4,
#  4,
#  3,
#  4,
#  3,
#  2,
#  8,
#  2,
#  3,
#  5,
#  3,
#  2,
#  9,
#  3,
#  3,
#  1,
#  4,
#  2,
#  5,
#  2,
#  7,
#  3,
#  1,
#  4,
#  1,
#  2,
#  4,
#  1,
#  3,
#  3,
#  3,
#  5,
#  3,
#  5,
#  2,
#  5,
#  1,
#  5,
#  4,
#  4,
#  4,
#  2,
#  1,
#  2,
#  5,
#  4,
#  1,
#  4,
#  1,
#  5,
#  4,
#  4,
#  3,
#  7,
#  2,
#  7,
#  3,
#  4,
#  2,
#  3,
#  7,
#  5,
#  4,
#  2,
#  2,
#  6,
#  1,
#  3,
#  4,
#  4,
#  9,
#  4,
#  4,
#  4,
#  1,
#  8,
#  5,
#  4,
#  10,
#  2,
#  8,
#  4,
#  5,
#  5,
#  1,
#  1,
#  2,
#  5,
#  4,
#  2,
#  1,
#  7,
#  4,
#  4,
#  12,
#  2,
#  6,
#  4,
#  1,
#  7,
#  4,
#  6,
#  4,
#  5,
#  2,
#  3,
#  4,
#  5,
#  4,
#  2,
#  4,
#  1,
#  2,
#  3,
#  4,
#  2,
#  1,
#  7,
#  2,
#  3,
#  2,
#  4,
#  2,
#  2,
#  3,
#  5,
#  5,
#  4,
#  5,
#  7,
#  2,
#  6,
#  2,
#  4,
#  2,
#  2,
#  4,
#  2,
#  7,
#  2,
#  5,
#  2,
#  4,
#  2,
#  4,
#  8,
#  1,
#  4,
#  4,
#  1,
#  5,
#  3,
#  4,
#  4,
#  6,
#  5,
#  2,
#  8,
#  5,
#  5,
#  9,
#  3,
#  4,
#  4,
#  4,
#  6,
#  5,
#  5,
#  6,
#  3,
#  3,
#  6,
#  2,
#  6,
#  4,
#  4,
#  8,
#  4,
#  3,
#  3,
#  13,
#  3,
#  2,
#  4,
#  8,
#  6,
#  3,
#  2,
#  2,
#  3,
#  9,
#  5,
#  7,
#  4,
#  10,
#  2,
#  1,
#  3,
#  5,
#  1,
#  4,
#  4,
#  1,
#  ...]

# %%
fdist = FreqDist(len(w) for w in word_tokens) 
print(fdist)
fdist
# Out:
# <FreqDist with 19 samples and 79804 outcomes>
# FreqDist({3: 18484, 4: 17727, 2: 12815, 5: 9295, 6: 6259, 7: 4900, 1: 4104, 8: 2715, 9: 1689, 10: 896, ...})

# %%
fdist.most_common()
# Out:
# [(3, 18484),
#  (4, 17727),
#  (2, 12815),
#  (5, 9295),
#  (6, 6259),
#  (7, 4900),
#  (1, 4104),
#  (8, 2715),
#  (9, 1689),
#  (10, 896),
#  (11, 465),
#  (12, 253),
#  (13, 139),
#  (14, 34),
#  (15, 16),
#  (17, 7),
#  (16, 4),
#  (20, 1),
#  (19, 1)]

# %%
fdist.freq(fdist.max())
# Out:
# 0.23161746278382037

# %%
len(text.split())
# Out:
# 82657

# %%
import re
parts = [len(l.split()) for l in re.split(r'[?!.]', text) if l.strip()]

print(sum(parts)/len(parts))
# Out:
# 13.229674153748814

# %%
import nltk
from nltk import pos_tag
nltk.pos_tag(freq)
# Out:
# [('chapter', 'NN'),
#  ('r', 'NN'),
#  ('shadow', 'NN'),
#  ('change', 'NN'),
#  ('harvest', 'NN'),
#  ('ended', 'VBD'),
#  ('summer', 'NN'),
#  ('gone', 'VBN'),
#  ('quoted', 'JJ'),
#  ('anne', 'NN'),
#  ('shirley', 'NN'),
#  ('gazing', 'VBG'),
#  ('across', 'IN'),
#  ('shorn', 'JJ'),
#  ('fields', 'NNS'),
#  ('dream', 'VBP'),
#  ('ily', 'RB'),
#  ('diana', 'JJ'),
#  ('barry', 'NN'),
#  ('picking', 'VBG'),
#  ('apples', 'NNS'),
#  ('green', 'JJ'),
#  ('gables', 'NNS'),
#  ('orchard', 'RB'),
#  ('resting', 'VBG'),
#  ('labours', 'NNS'),
#  ('sunny', 'JJ'),
#  ('corner', 'NN'),
#  ('airy', 'JJ'),
#  ('fleets', 'NNS'),
#  ('thistledown', 'RP'),
#  ('drifted', 'JJ'),
#  ('wings', 'NNS'),
#  ('wind', 'VBP'),
#  ('still', 'RB'),
#  ('summersweet', 'JJ'),
#  ('incense', 'JJ'),
#  ('ferns', 'NNS'),
#  ('haunted', 'VBN'),
#  ('wood', 'NN'),
#  ('everything', 'NN'),
#  ('landscape', 'NN'),
#  ('around', 'IN'),
#  ('spoke', 'VBD'),
#  ('autumn', 'NN'),
#  ('sea', 'NN'),
#  ('roaring', 'VBG'),
#  ('hollowly', 'RB'),
#  ('dis', 'JJ'),
#  ('tance', 'NN'),
#  ('bare', 'NN'),
#  ('sere', 'JJ'),
#  ('scarfed', 'VBN'),
#  ('golden', 'JJ'),
#  ('rod', 'NN'),
#  ('brook', 'NN'),
#  ('valley', 'NN'),
#  ('overflowed', 'VBD'),
#  ('asters', 'NNS'),
#  ('ethereal', 'JJ'),
#  ('purple', 'JJ'),
#  ('lake', 'NN'),
#  ('shining', 'VBG'),
#  ('waters', 'NNS'),
#  ('blue', 'JJ'),
#  ('changeful', 'JJ'),
#  ('spring', 'NN'),
#  ('pale', 'JJ'),
#  ('azure', 'NN'),
#  ('clear', 'JJ'),
#  ('steadfast', 'JJ'),
#  ('serene', 'JJ'),
#  ('water', 'NN'),
#  ('past', 'IN'),
#  ('moods', 'NNS'),
#  ('tenses', 'NNS'),
#  ('emotion', 'NN'),
#  ('settled', 'VBD'),
#  ('tranquillity', 'NN'),
#  ('unbroken', 'JJ'),
#  ('fickle', 'JJ'),
#  ('dreams', 'NNS'),
#  ('nice', 'RB'),
#  ('said', 'VBD'),
#  ('twisting', 'VBG'),
#  ('island', 'NN'),
#  ('9', 'CD'),
#  ('new', 'JJ'),
#  ('ring', 'NN'),
#  ('left', 'VBD'),
#  ('hand', 'NN'),
#  ('smile', 'NN'),
#  ('miss', 'NN'),
#  ('lavendars', 'NNS'),
#  ('wedding', 'VBG'),
#  ('seemed', 'VBD'),
#  ('come', 'JJ'),
#  ('sort', 'NN'),
#  ('suppose', 'VBD'),
#  ('crown', 'JJ'),
#  ('mr', 'NN'),
#  ('mrs', 'NN'),
#  ('irving', 'VBG'),
#  ('pacific', 'JJ'),
#  ('coast', 'NN'),
#  ('seems', 'VBZ'),
#  ('long', 'RB'),
#  ('enough', 'RB'),
#  ('go', 'VBP'),
#  ('world', 'NN'),
#  ('sighed', 'VBN'),
#  ('cant', 'JJ'),
#  ('believe', 'VBP'),
#  ('week', 'NN'),
#  ('since', 'IN'),
#  ('married', 'VBN'),
#  ('changed', 'VBN'),
#  ('lavendar', 'NN'),
#  ('allan', 'NN'),
#  ('lonely', 'RB'),
#  ('manse', 'JJ'),
#  ('looks', 'VBZ'),
#  ('shutters', 'NNS'),
#  ('closed', 'VBD'),
#  ('went', 'VBD'),
#  ('last', 'JJ'),
#  ('night', 'NN'),
#  ('made', 'VBD'),
#  ('feel', 'NN'),
#  ('well', 'RB'),
#  ('everybody', 'NN'),
#  ('died', 'VBD'),
#  ('never', 'RB'),
#  ('get', 'VB'),
#  ('another', 'DT'),
#  ('minister', 'NN'),
#  ('gloomy', 'NN'),
#  ('conviction', 'NN'),
#  ('sup', 'VBD'),
#  ('pose', 'JJ'),
#  ('kinds', 'NNS'),
#  ('supplies', 'NNS'),
#  ('winter', 'VBP'),
#  ('half', 'NN'),
#  ('sundays', 'NNS'),
#  ('preaching', 'VBG'),
#  ('gilbert', 'NN'),
#  ('awfully', 'RB'),
#  ('dull', 'JJ'),
#  ('fred', 'VBN'),
#  ('insinuated', 'JJ'),
#  ('slyly', 'NN'),
#  ('lynde', 'NN'),
#  ('going', 'VBG'),
#  ('move', 'NN'),
#  ('asked', 'VBD'),
#  ('heard', 'JJ'),
#  ('annes', 'NNS'),
#  ('remark', 'NN'),
#  ('tomorrow', 'NN'),
#  ('im', 'NN'),
#  ('glad', 'JJ'),
#  ('shes', 'NNS'),
#  ('coming', 'VBG'),
#  ('marilla', 'NN'),
#  ('cleared', 'VBD'),
#  ('know', 'JJ'),
#  ('spare', 'JJ'),
#  ('room', 'NN'),
#  ('yesterday', 'NN'),
#  ('hated', 'VBD'),
#  ('course', 'NN'),
#  ('silly', 'RB'),
#  ('seem', 'VBP'),
#  ('committing', 'VBG'),
#  ('sacrilege', 'NN'),
#  ('old', 'JJ'),
#  ('always', 'RB'),
#  ('like', 'IN'),
#  ('shrine', 'JJ'),
#  ('child', 'NN'),
#  ('thought', 'VBD'),
#  ('wonderful', 'JJ'),
#  ('apartment', 'NN'),
#  ('suming', 'VBG'),
#  ('desire', 'NN'),
#  ('remember', 'VB'),
#  ('sleep', 'JJ'),
#  ('bed', 'NN'),
#  ('would', 'MD'),
#  ('terrible', 'VB'),
#  ('con', 'NN'),
#  ('oh', 'IN'),
#  ('—i', 'NNP'),
#  ('couldnt', 'NN'),
#  ('slept', 'VBD'),
#  ('wink', 'WP'),
#  ('awe', 'IN'),
#  ('3', 'CD'),
#  ('walked', 'VBD'),
#  ('sent', 'VBN'),
#  ('errand', 'NN'),
#  ('tiptoed', 'NN'),
#  ('held', 'VBD'),
#  ('breath', 'JJ'),
#  ('church', 'NN'),
#  ('felt', 'VBD'),
#  ('relieved', 'JJ'),
#  ('indeed', 'RB'),
#  ('got', 'VBD'),
#  ('pictures', 'NNS'),
#  ('george', 'VBP'),
#  ('whitefield', 'JJ'),
#  ('duke', 'NN'),
#  ('welling', 'VBG'),
#  ('ton', 'NN'),
#  ('hung', 'VBD'),
#  ('one', 'CD'),
#  ('side', 'NN'),
#  ('mirror', 'NN'),
#  ('frowned', 'VBD'),
#  ('sternly', 'JJ'),
#  ('time', 'NN'),
#  ('espe', 'VBZ'),
#  ('cially', 'RB'),
#  ('dared', 'JJ'),
#  ('peep', 'NN'),
#  ('house', 'NN'),
#  ('didnt', 'NN'),
#  ('twist', 'NN'),
#  ('face', 'NN'),
#  ('little', 'JJ'),
#  ('wondered', 'JJ'),
#  ('houseclean', 'NN'),
#  ('cleaned', 'VBD'),
#  ('stripped', 'VBD'),
#  ('rele', 'JJ'),
#  ('passes', 'NNS'),
#  ('glory', 'NN'),
#  ('concluded', 'VBD'),
#  ('laugh', 'JJ'),
#  ('note', 'NN'),
#  ('regret', 'NN'),
#  ('pleasant', 'NN'),
#  ('gated', 'VBD'),
#  ('upstairs', 'JJ'),
#  ('hall', 'NN'),
#  ('shrines', 'NNS'),
#  ('desecrated', 'VBD'),
#  ('even', 'RB'),
#  ('outgrown', 'JJ'),
#  ('ill', 'JJ'),
#  ('lonesome', 'NN'),
#  ('moaned', 'VBD'),
#  ('hundredth', 'JJ'),
#  ('think', 'VBP'),
#  ('next', 'JJ'),
#  ('together', 'RB'),
#  ('cheerily', 'RB'),
#  ('mustnt', 'VB'),
#  ('let', 'NN'),
#  ('rob', 'VB'),
#  ('us', 'PRP'),
#  ('weeks', 'NNS'),
#  ('joy', 'VBP'),
#  ('hate', 'JJ'),
#  ('home', 'NN'),
#  ('talk', 'NN'),
#  ('groan', 'NN'),
#  ('youll', 'NN'),
#  ('number', 'NN'),
#  ('friends', 'VBZ'),
#  ('shall', 'MD'),
#  ('alone', 'RB'),
#  ('among', 'IN'),
#  ('strangers', 'NNS'),
#  ('knowing', 'VBG'),
#  ('soul', 'NN'),
#  ('good', 'JJ'),
#  ('except', 'IN'),
#  ('charlie', 'NNS'),
#  ('sloane', 'VBP'),
#  ('imitating', 'VBG'),
#  ('italics', 'NNS'),
#  ('slyness', 'JJ'),
#  ('great', 'JJ'),
#  ('comfort', 'NN'),
#  ('4', 'CD'),
#  ('agreed', 'VBD'),
#  ('sarcastically', 'RB'),
#  ('whereupon', 'JJ'),
#  ('irre', 'JJ'),
#  ('knew', 'VBD'),
#  ('exactly', 'RB'),
#  ('despite', 'IN'),
#  ('sundry', 'JJ'),
#  ('sponsible', 'JJ'),
#  ('damsels', 'NNS'),
#  ('laughed', 'VBN'),
#  ('confidential', 'JJ'),
#  ('talks', 'NNS'),
#  ('blythe', 'VBP'),
#  ('sure', 'JJ'),
#  ('boys', 'NNS'),
#  ('may', 'MD'),
#  ('boarding', 'VBG'),
#  ('end', 'VB'),
#  ('kingsport', 'NN'),
#  ('redmond', 'NN'),
#  ('wont', 'NN'),
#  ('first', 'RB'),
#  ('shant', 'JJ'),
#  ('looking', 'VBG'),
#  ('ward', 'JJ'),
#  ('weekend', 'NN'),
#  ('visit', 'NN'),
#  ('queens', 'VBZ'),
#  ('christmas', 'JJ'),
#  ('thousand', 'CD'),
#  ('years', 'NNS'),
#  ('away', 'RB'),
#  ('changing', 'VBG'),
#  ('sadly', 'RB'),
#  ('parting', 'VBG'),
#  ('thoughtfully', 'RB'),
#  ('feeling', 'VBG'),
#  ('things', 'NNS'),
#  ('ways', 'NNS'),
#  ('grownup', 'VBP'),
#  ('really', 'RB'),
#  ('used', 'VBN'),
#  ('imagine', 'NN'),
#  ('children', 'NNS'),
#  ('dont', 'VBP'),
#  ('answered', 'JJ'),
#  ('caressing', 'NN'),
#  ('effect', 'NN'),
#  ('making', 'VBG'),
#  ('suddenly', 'RB'),
#  ('inexperienced', 'VBD'),
#  ('many', 'JJ'),
#  ('puzzling', 'VBG'),
#  ('sometimes', 'RB'),
#  ('frightened', 'VBN'),
#  ('give', 'JJ'),
#  ('anything', 'NN'),
#  ('girl', 'JJ'),
#  ('•the', 'NNP'),
#  ('cheerfully', 'RB'),
#  ('unexpected', 'VBD'),
#  ('5', 'CD'),
#  ('though', 'IN'),
#  ('fancy', 'JJ'),
#  ('spice', 'NN'),
#  ('life', 'NN'),
#  ('eighteen', 'JJ'),
#  ('two', 'CD'),
#  ('twenty', 'JJ'),
#  ('age', 'NN'),
#  ('ten', 'NN'),
#  ('staid', 'VBD'),
#  ('maid', 'JJ'),
#  ('aunt', 'NN'),
#  ('middleaged', 'VBD'),
#  ('matron', 'NN'),
#  ('vacations', 'NNS'),
#  ('keep', 'VBP'),
#  ('di', 'NN'),
#  ('darling', 'VBG'),
#  ('maids', 'NNS'),
#  ('aspire', 'NN'),
#  ('rooms', 'NNS'),
#  ('umble', 'JJ'),
#  ('uriah', 'JJ'),
#  ('heep', 'NN'),
#  ('quite', 'RB'),
#  ('content', 'JJ'),
#  ('overtheporch', 'NN'),
#  ('offthe', 'IN'),
#  ('parlour', 'JJ'),
#  ('cubby', 'NN'),
#  ('hole', 'NN'),
#  ('nonsense', 'NN'),
#  ('marry', 'NN'),
#  ('somebody', 'NN'),
#  ('splendid', 'JJ'),
#  ('handsome', 'NN'),
#  ('rich', 'JJ'),
#  ('avonlea', 'NN'),
#  ('gor', 'NN'),
#  ('turn', 'VBP'),
#  ('nose', 'JJ'),
#  ('youth', 'NN'),
#  ('pity', 'NN'),
#  ('geous', 'JJ'),
#  ('fear', 'NN'),
#  ('turning', 'VBG'),
#  ('spoil', 'NN'),
#  ('patting', 'VBG'),
#  ('shapely', 'RB'),
#  ('organ', 'JJ'),
#  ('havent', 'NN'),
#  ('features', 'NNS'),
#  ('could', 'MD'),
#  ('afford', 'VB'),
#  ('king', 'VBG'),
#  ('cannibal', 'JJ'),
#  ('islands', 'NNS'),
#  ('gay', 'JJ'),
#  ('girls', 'NNS'),
#  ('separated', 'VBD'),
#  ('promise', 'JJ'),
#  ('return', 'NN'),
#  ('slope', 'NN'),
#  ('walk', 'VBP'),
#  ('post', 'NN'),
#  ('office', 'NN'),
#  ('found', 'VBD'),
#  ('letter', 'NN'),
#  ('awaiting', 'VBG'),
#  ('overtook', 'NN'),
#  ('bridge', 'NN'),
#  ('excitement', 'NN'),
#  ('sparkling', 'VBG'),
#  ('6', 'CD'),
#  ('priscilla', 'NN'),
#  ('grant', 'NN'),
#  ('isnt', 'NN'),
#  ('exclaimed', 'VBD'),
#  ('hoped', 'VBD'),
#  ('father', 'RB'),
#  ('consent', 'NN'),
#  ('however', 'RB'),
#  ('board', 'NN'),
#  ('fell', 'VBD'),
#  ('phalanx', 'RB'),
#  ('army', 'JJ'),
#  ('banners', 'NNS'),
#  ('sors', 'NNS'),
#  ('profes', 'VBP'),
#  ('chum', 'JJ'),
#  ('burg', 'NN'),
#  ('tell', 'NN'),
#  ('finest', 'JJS'),
#  ('natural', 'JJ'),
#  ('park', 'NN'),
#  ('ive', 'JJ'),
#  ('scenery', 'NN'),
#  ('magnificent', 'NN'),
#  ('wonder', 'NN'),
#  ('beau', 'NN'),
#  ('tiful', 'NN'),
#  ('murmured', 'VBD'),
#  ('loving', 'NN'),
#  ('enraptured', 'JJ'),
#  ('eyes', 'NNS'),
#  ('must', 'MD'),
#  ('loveliest', 'VB'),
#  ('spot', 'NN'),
#  ('matter', 'NN'),
#  ('fairer', 'NN'),
#  ('lands', 'VBZ'),
#  ('lie', 'JJ'),
#  ('alien', 'JJ'),
#  ('stars', 'NNS'),
#  ('leaning', 'VBG'),
#  ('pond', 'NN'),
#  ('drinking', 'NN'),
#  ('deep', 'JJ'),
#  ('enchantment', 'NN'),
#  ('dusk', 'NN'),
#  ('climbed', 'VBD'),
#  ('sinking', 'JJ'),
#  ('dory', 'JJ'),
#  ('day', 'NN'),
#  ('elaine', 'VB'),
#  ('floated', 'VBN'),
#  ('camelot', 'NN'),
#  ('fine', 'JJ'),
#  ('empurpling', 'VBG'),
#  ('dye', 'NN'),
#  ('sunset', 'NN'),
#  ('stained', 'VBD'),
#  ('western', 'JJ'),
#  ('skies', 'NNS'),
#  ('moon', 'VBP'),
#  ('rising', 'VBG'),
#  ('lay', 'NN'),
#  ('silver', 'NN'),
#  ('light', 'JJ'),
#  ('remem', 'NN'),
#  ('brance', 'NN'),
#  ('wove', 'VBD'),
#  ('sweet', 'JJ'),
#  ('subtle', 'JJ'),
#  ('spell', 'NN'),
#  ('young', 'JJ'),
#  ('creatures', 'NNS'),
#  ('quiet', 'JJ'),
#  ('afraid', 'JJ'),
#  ('speak', 'NN'),
#  ('derful', 'JJ'),
#  ('beauty', 'NN'),
#  ('vanish', 'JJ'),
#  ('broken', 'VBN'),
#  ('silence', 'NN'),
#  ('breathed', 'VBN'),
#  ('laid', 'JJ'),
#  ('slender', 'NN'),
#  ('white', 'JJ'),
#  ('lying', 'VBG'),
#  ('rail', 'NN'),
#  ('7', 'CD'),
#  ('hazel', 'NN'),
#  ('deepened', 'VBD'),
#  ('darkness', 'JJ'),
#  ('boyish', 'JJ'),
#  ('lips', 'NNS'),
#  ('opened', 'VBD'),
#  ('something', 'NN'),
#  ('hope', 'NN'),
#  ('thrilled', 'VBD'),
#  ('snatched', 'JJ'),
#  ('turned', 'VBD'),
#  ('say', 'VBP'),
#  ('rather', 'RB'),
#  ('quickly', 'RB'),
#  ('overdone', 'VB'),
#  ('carelessness', 'NN'),
#  ('headache', 'NN'),
#  ('afternoon', 'NN'),
#  ('twins', 'NNS'),
#  ('dread', 'VBP'),
#  ('ful', 'JJ'),
#  ('mischief', 'NN'),
#  ('shouldnt', 'NN'),
#  ('stayed', 'VBD'),
#  ('chattered', 'VBN'),
#  ('ceaselessly', 'RB'),
#  ('inconsequentially', 'RB'),
#  ('poor', 'JJ'),
#  ('reached', 'VBD'),
#  ('lane', 'NN'),
#  ('hardly', 'RB'),
#  ('chance', 'NN'),
#  ('word', 'NN'),
#  ('edgewise', 'NN'),
#  ('parted', 'VBN'),
#  ('secret', 'JJ'),
#  ('selfconsciousness', 'JJ'),
#  ('heart', 'NN'),
#  ('regard', 'NN'),
#  ('ever', 'RB'),
#  ('fleeting', 'JJ'),
#  ('moment', 'NN'),
#  ('tion', 'NN'),
#  ('garden', 'NN'),
#  ('echo', 'NN'),
#  ('lodge', 'NN'),
#  ('revela', 'NN'),
#  ('intruded', 'VBD'),
#  ('perfect', 'JJ'),
#  ('schoolday', 'JJ'),
#  ('comrade', 'NN'),
#  ('ship', 'NN'),
#  ('threatened', 'VBD'),
#  ('mar', 'NNS'),
#  ('see', 'VBP'),
#  ('halfresentfully', 'RB'),
#  ('spoiled', 'VBN'),
#  ('sensible', 'JJ'),
#  ('halfsorrowfully', 'RB'),
#  ('goes', 'VBZ'),
#  ('friendship', 'JJ'),
#  ('uneasy', 'JJ'),
#  ('doubt', 'NN'),
#  ('strictly', 'RB'),
#  ('warm', 'JJ'),
#  ('pressure', 'NN'),
#  ('gilberts', 'NNS'),
#  ('distinctly', 'RB'),
#  ('swift', 'JJ'),
#  ('second', 'JJ'),
#  ('rested', 'VBN'),
#  ('less', 'JJR'),
#  ('sensation', 'NN'),
#  ('far', 'RB'),
#  ('8', 'CD'),
#  ('unpleasant', 'JJ'),
#  ('different', 'JJ'),
#  ('attended', 'VBD'),
#  ('similar', 'JJ'),
#  ('demonstration', 'NN'),
#  ('sloanes', 'NNS'),
#  ('part', 'NN'),
#  ('sitting', 'VBG'),
#  ('dance', 'NN'),
#  ('sands', 'NNS'),
#  ('party', 'NN'),
#  ('three', 'CD'),
#  ('nights', 'NNS'),
#  ('shivered', 'VBD'),
#  ('disagreeable', 'JJ'),
#  ('recollection', 'NN'),
#  ('problems', 'NNS'),
#  ('connected', 'VBN'),
#  ('infatuated', 'JJ'),
#  ('swains', 'NNS'),
#  ('vanished', 'VBD'),
#  ('mind', 'NN'),
#  ('entered', 'VBD'),
#  ('homely', 'RB'),
#  ('unsenti', 'JJ'),
#  ('mental', 'NN'),
#  ('atmosphere', 'RB'),
#  ('kitchen', 'VBZ'),
#  ('eightyearold', 'JJ'),
#  ('su', 'NN'),
#  ('boy', 'NN'),
#  ('crying', 'VBG'),
#  ('grievously', 'RB'),
#  ('sofa', 'JJ'),
#  ('davy', 'NN'),
#  ('arms', 'NNS'),
#  ('taking', 'VBG'),
#  ('dora', 'JJ'),
#  ('manilas', 'NNS'),
#  ('putting', 'VBG'),
#  ('sobbed', 'NN'),
#  ('cause', 'NN'),
#  ('outside', 'IN'),
#  ('cellar', 'JJ'),
#  ('steps', 'NNS'),
#  ('heels', 'NNS'),
#  ('head', 'VBP'),
#  ('scraped', 'VBD'),
#  ('skin', 'JJ'),
#  ('cry', 'NN'),
#  ('dear', 'NN'),
#  ('sorry', 'NN'),
#  ('help', 'NN'),
#  ('shell', 'VB'),
#  ('right', 'JJ'),
#  ('helps', 'NNS'),
#  ('aint', 'VB'),
#  ('cutting', 'VBG'),
#  ('short', 'JJ'),
#  ('wellmeant', 'JJ'),
#  ('increasing', 'VBG'),
#  ('bitterness', 'NN'),
#  ('wasnt', 'NN'),
#  ('fall', 'NN'),
#  ('preachment', 'NN'),
#  ('davyboy', 'NN'),
#  ('missing', 'VBG'),
#  ('fun', 'NN'),
#  ('laughter', 'NN'),
#  ('choked', 'VBD'),
#  ('back', 'RB'),
#  ('unholy', 'JJ'),
#  ('shriek', 'NN'),
#  ('call', 'NN'),
#  ('hurt', 'VBD'),
#  ('much', 'RB'),
#  ('defiantly', 'RB'),
#  ('shed', 'VBN'),
#  ('killed', 'VBN'),
#  ('op', 'RB'),
#  ('id', 'JJ'),
#  ('real', 'JJ'),
#  ('keiths', 'NNS'),
#  ('easy', 'JJ'),
#  ('theyre', 'JJ'),
#  ('blewetts', 'NN'),
#  ('guess', 'NN'),
#  ('herb', 'NN'),
#  ('blewett', 'NN'),
#  ('hayloft', 'NN'),
#  ('wednesday', 'NN'),
#  ('rolled', 'VBD'),
#  ('turnip', 'JJ'),
#  ('chute', 'NN'),
#  ('box', 'NN'),
#  ('stall', 'NN'),
#  ('fearful', 'JJ'),
#  ('wild', 'JJ'),
#  ('cross', 'NN'),
#  ('horse', 'NN'),
#  ('alive', 'JJ'),
#  ('bones', 'NNS'),
#  ('broke', 'VBD'),
#  ('says', 'VBZ'),
#  ('folks', 'NNS'),
#  ('kill', 'VB'),
#  ('meataxe', 'JJ'),
#  ('morrow', 'JJ'),
#  ('yes', 'NNS'),
#  ('perhaps', 'RB'),
#  ('put', 'VBD'),
#  ('decidedly', 'RB'),
#  ('prayers', 'NNS'),
#  ('likes', 'VBP'),
#  ('em', 'JJ'),
#  ('god', 'NN'),
#  ('wait', 'NN'),
#  ('till', 'NN'),
#  ('forget', 'VB'),
#  ('bet', 'IN'),
#  ('saying', 'VBG'),
#  ('ing', 'VBG'),
#  ('wish', 'JJ'),
#  ('youd', 'NNS'),
#  ('stay', 'VBP'),
#  ('want', 'VBP'),
#  ('leave', 'VBP'),
#  ('10', 'CD'),
#  ('ought', 'JJ'),
#  ('youre', 'NN'),
#  ('neednt', 'JJ'),
#  ('grown', 'JJ'),
#  ('single', 'JJ'),
#  ('thing', 'NN'),
#  ('find', 'VB'),
#  ('catch', 'NN'),
#  ('flatly', 'RB'),
#  ('rillall', 'JJ'),
#  ('send', 'VBP'),
#  ('grow', 'NN'),
#  ('therell', 'NN'),
#  ('nobody', 'NN'),
#  ('milty', 'NN'),
#  ('boulter', 'NN'),
#  ('college', 'NN'),
#  ('mother', 'NN'),
#  ('man', 'NN'),
#  ('burned', 'VBD'),
#  ('resentment', 'JJ'),
#  ('reminding', 'VBG'),
#  ('boulters', 'NNS'),
#  ('crude', 'VBP'),
#  ('vulgarity', 'NN'),
#  ('speech', 'NN'),
#  ('harm', 'NN'),
#  ('study', 'NN'),
#  ('learn', 'NN'),
#  ('shoes', 'NNS'),
#  ('ships', 'NNS'),
#  ('sealing', 'VBG'),
#  ('wax', 'NN'),
#  ('cabbages', 'NNS'),
#  ('kings', 'NNS'),
#  ('persisted', 'VBD'),
#  ('subject', 'JJ'),
#  ('evidently', 'RB'),
#  ('possessed', 'VBD'),
#  ('certain', 'JJ'),
#  ('fascina', 'RB'),
#  ('better', 'RBR'),
#  ('ask', 'VB'),
#  ('lessly', 'RB'),
#  ('process', 'NN'),
#  ('likely', 'JJ'),
#  ('knows', 'VBZ'),
#  ('gravely', 'RB'),
#  ('cried', 'JJ'),
#  ('realizing', 'VBG'),
#  ('11', 'CD'),
#  ('mistake', 'NN'),
#  ('told', 'VBD'),
#  ('protested', 'VBN'),
#  ('ag', 'RB'),
#  ('grieved', 'VBN'),
#  ('decreed', 'JJ'),
#  ('way', 'NN'),
#  ('getting', 'VBG'),
#  ('scrape', 'NN'),
#  ('wandered', 'VBD'),
#  ('victoria', 'NNS'),
#  ('sat', 'VBD'),
#  ('curtained', 'VBN'),
#  ('moonlit', 'NN'),
#  ('gloom', 'NN'),
#  ('duet', 'NN'),
#  ('finespun', 'NN'),
#  ('loved', 'VBD'),
#  ('spun', 'JJ'),
#  ('days', 'NNS'),
#  ('lovelorn', 'VBN'),
#  ('youths', 'JJ'),
#  ('neighbours', 'NNS'),
#  ('ence', 'NN'),
#  ('cayenne', 'NN'),
#  ('speeches', 'NNS'),
#  ('forgot', 'VBD'),
#  ('malicious', 'JJ'),
#  ('girlish', 'JJ'),
#  ('exist', 'VBP'),
#  ('imagination', 'NN'),
#  ('sailed', 'VBD'),
#  ('storied', 'JJ'),
#  ('seas', 'NNS'),
#  ('wash', 'VBP'),
#  ('distant', 'JJ'),
#  ('shores', 'NNS'),
#  ('faery', 'VBP'),
#  ('lorn', 'JJ'),
#  ('lost', 'VBN'),
#  ('atlantis', 'NN'),
#  ('elysium', 'NN'),
#  ('evening', 'VBG'),
#  ('star', 'NN'),
#  ('pilot', 'NN'),
#  ('land', 'NN'),
#  ('hearts', 'VBZ'),
#  ('richer', 'JJR'),
#  ('realities', 'NNS'),
#  ('seen', 'VBN'),
#  ('pass', 'NN'),
#  ('un', 'JJ'),
#  ('eternal', 'JJ'),
#  ('garlands', 'NNS'),
#  ('following', 'VBG'),
#  ('numerable', 'JJ'),
#  ('ii', 'NN'),
#  ('sped', 'VBD'),
#  ('swiftly', 'RB'),
#  ('crowded', 'VBN'),
#  ('called', 'VBN'),
#  ('bye', 'NN'),
#  ('calls', 'VBZ'),
#  ('received', 'VBN'),
#  ('otherwise', 'RB'),
#  ('according', 'VBG'),
#  ('whether', 'IN'),
#  ('callers', 'NNS'),
#  ('calledupon', 'VBP'),
#  ('heartily', 'RB'),
#  ('sympathy', 'JJ'),
#  ('hopes', 'NNS'),
#  ('puffedup', 'VBP'),
#  ('col', 'JJ'),
#  ('lege', 'JJ'),
#  ('duty', 'NN'),
#  ('take', 'VB'),
#  ('peg', 'NN'),
#  ('avis', 'NNS'),
#  ('gave', 'VBD'),
#  ('farewell', 'RB'),
#  ('honour', 'JJ'),
#  ('josie', 'NN'),
#  ('pye', 'NN'),
#  ('choosing', 'VBG'),
#  ('place', 'NN'),
#  ('partly', 'RB'),
#  ('pyes', 'VBZ'),
#  ('large', 'JJ'),
#  ('convenient', 'NN'),
#  ('strongly', 'RB'),
#  ('suspected', 'VBD'),
#  ('nothing', 'NN'),
#  ('affair', 'NN'),
#  ('accepted', 'VBD'),
#  ('offer', 'NN'),
#  ('gracious', 'JJ'),
#  ('harmony', 'NN'),
#  ('occasion', 'NN'),
#  ('amiable', 'JJ'),
#  ('unusually', 'RB'),
#  ('remarked', 'JJ'),
#  ('descendingly', 'RB'),
#  ('dress', 'JJ'),
#  ('becoming', 'VBG'),
#  ('look', 'NN'),
#  ('almost', 'RB'),
#  ('pretty', 'RB'),
#  ('kind', 'NN'),
#  ('responded', 'VBD'),
#  ('dancing', 'VBG'),
#  ('sense', 'NN'),
#  ('li', 'FW'),
#  ('humour', 'PRP$'),
#  ('develop', 'VB'),
#  ('four', 'CD'),
#  ('amusement', 'NN'),
#  ('teen', 'NN'),
#  ('merely', 'RB'),
#  ('food', 'NN'),
#  ('laughing', 'VBG'),
#  ('behind', 'IN'),
#  ('wicked', 'JJ'),
#  ('contented', 'VBD'),
#  ('whis', 'JJ'),
#  ('pering', 'NN'),
#  ('gertie', 'NN'),
#  ('downstairs', 'VBZ'),
#  ('airs', 'RP'),
#  ('zest', 'JJS'),
#  ('crowd', 'NN'),
#  ('youthful', 'JJ'),
#  ('full', 'JJ'),
#  ('mirth', 'NN'),
#  ('lightheartedness', 'NN'),
#  ('rosy', 'NN'),
#  ('dimpled', 'VBD'),
#  ('shadowed', 'VBN'),
#  ('faithful', 'JJ'),
#  ('jane', 'NN'),
#  ('andrews', 'NNS'),
#  ('neat', 'VBP'),
#  ('plain', 'JJ'),
#  ('ruby', 'NN'),
#  ('gillis', 'NN'),
#  ('handsomest', 'NN'),
#  ('brightest', 'NN'),
#  ('cream', 'NN'),
#  ('silk', 'NN'),
#  ('blouse', 'NN'),
#  ('red', 'VBD'),
#  ('geraniums', 'NNS'),
#  ('hair', 'NN'),
#  ('trying', 'VBG'),
#  ('near', 'IN'),
#  ('elusive', 'JJ'),
#  ('possible', 'JJ'),
#  ('carrie', 'NN'),
#  ('melancholy', 'NN'),
#  ('reported', 'VBD'),
#  ('allow', 'JJ'),
#  ('oliver', 'RB'),
#  ('kimball', 'VB'),
#  ('moody', 'NN'),
#  ('spurgeon', 'JJ'),
#  ('macpherson', 'NN'),
#  ('whose', 'WP$'),
#  ('round', 'NN'),
#  ('objectionable', 'JJ'),
#  ('ears', 'NNS'),
#  ('objec', 'VBP'),
#  ('tionable', 'JJ'),
#  ('billy', 'RB'),
#  ('chuckled', 'VBN'),
#  ('watched', 'VBN'),
#  ('grin', 'JJ'),
#  ('pleasure', 'NN'),
#  ('broad', 'JJ'),
#  ('freckled', 'VBD'),
#  ('countenance', 'NN'),
#  ('known', 'VBN'),
#  ('beforehand', 'NN'),
#  ('founders', 'NNS'),
#  ('society', 'NN'),
#  ('presented', 'VBN'),
#  ('complimentary', 'JJ'),
#  ('address', 'NN'),
#  ('tokens', 'NNS'),
#  ('respect', 'JJ'),
#  ('case', 'NN'),
#  ('volume', 'NN'),
#  ('shakespeares', 'NNS'),
#  ('plays', 'VBZ'),
#  ('fountain', 'VBP'),
#  ('pen', 'JJ'),
#  ('taken', 'VBN'),
#  ('surprise', 'NN'),
#  ('14', 'CD'),
#  ('pleased', 'JJ'),
#  ('read', 'JJ'),
#  ('spurgeons', 'NNS'),
#  ('solemn', 'VBP'),
#  ('ministerial', 'JJ'),
#  ('tones', 'NNS'),
#  ('tears', 'NNS'),
#  ('drowned', 'VBD'),
#  ('sparkle', 'JJ'),
#  ('big', 'JJ'),
#  ('gray', 'NN'),
#  ('worked', 'VBD'),
#  ('hard', 'JJ'),
#  ('faithfully', 'RB'),
#  ('avi', 'VBP'),
#  ('warmed', 'JJ'),
#  ('cockles', 'NNS'),
#  ('members', 'NNS'),
#  ('appreciated', 'VBD'),
#  ('efforts', 'NNS'),
#  ('sincerely', 'RB'),
#  ('friendly', 'JJ'),
#  ('jolly', 'RB'),
#  ('merits', 'NNS'),
#  ('enjoyed', 'VBD'),
#  ('tremendously', 'RB'),
#  ('sentimental', 'JJ'),
#  ('ate', 'NN'),
#  ('supper', 'NN'),
#  ('verandah', 'NN'),
#  ('punish', 'NN'),
#  ('allowed', 'VBD'),
#  ('latter', 'JJ'),
#  ('revenge', 'NN'),
#  ('hurts', 'VBZ'),
#  ...]
